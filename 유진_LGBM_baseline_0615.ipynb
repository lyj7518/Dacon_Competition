# %% [markdown]
# # 데이터 합치기

# %%
import pandas as pd

def csv_r(name):
    file_name = "/content/drive/MyDrive/공모전/데이터/" + name + ".csv"
    df = pd.read_csv(file_name)
    df.index = df.iloc[:,0]
    df = df.iloc[:,1:]
    return df

df_jh = csv_r("지현_feature_220614")
df_yj = csv_r("유진_feature_220614")
df_ex = csv_r("수출금액")
df_tg = csv_r("our_target")

# %%
df = pd.concat([df_jh, df_yj, df_ex, df_tg], axis=1)
df
# Out:
#          산업생산지수_lag_6  일본_산업생산지수_lag_6  미국_산업생산지수_lag_6  선행종합지수_lag_6  \
# 2001-01          51.0            106.5             92.4          59.3
# 2001-02          51.8            108.0             92.1          59.8
# 2001-03          50.6            105.8             92.5          59.5
# 2001-04          50.2            107.4             92.2          58.8
# 2001-05          49.5            107.8             92.2          57.5
# ...               ...              ...              ...           ...
# 2021-08         115.4             96.1             95.5         124.1
# 2021-09         114.8             97.3             98.3         124.8
# 2021-10         112.9             98.5             98.4         125.6
# 2021-11         112.7             92.6             99.0         126.4
# 2021-12         114.3             98.7             99.6         127.1
#
#          기업경기실사지수_lag6  미국_환율_lag6  중국_환율_lag6  일본_환율_lag6  CD_lag6    회사채  \
# 2001-01            NaN     1114.86  134.656312     1033.62     7.15    NaN
# 2001-02            NaN     1114.57  134.616407     1031.23     7.04    NaN
# 2001-03            NaN     1116.50  134.867428     1044.85     7.05    NaN
# 2001-04            NaN     1127.31  136.171575     1040.25     7.04    NaN
# 2001-05            NaN     1151.15  139.071448     1057.17     6.99    NaN
# ...                ...         ...         ...         ...      ...    ...
# 2021-08          101.0     1111.72  172.340000     1055.14     0.73  1.313
# 2021-09          112.0     1131.02  173.760000     1040.86     0.75  1.494
# 2021-10          120.0     1119.40  171.440000     1025.98     0.74  1.506
# 2021-11          131.0     1123.28  174.550000     1029.14     0.68  1.523
# 2021-12          126.0     1121.30  174.660000     1018.50     0.66  1.667
#
#          ...  한국의대베트남수출_lag6m  한국의대홍콩수출_lag6m  한국의대일본수출_lag6m  \
# 2001-01  ...     137,391,132     870,993,704   1,645,587,937
# 2001-02  ...     121,056,169     923,675,716   1,678,044,413
# 2001-03  ...     127,921,283     943,856,029   1,900,124,085
# 2001-04  ...     126,551,005     981,958,017   1,773,514,357
# 2001-05  ...     150,756,897     944,141,978   1,877,923,709
# ...      ...              ...             ...             ...
# 2021-08  ...   3,907,994,035   2,516,268,543   2,191,909,157
# 2021-09  ...   4,207,078,759   3,402,418,498   2,415,077,031
# 2021-10  ...   4,334,987,144   2,985,366,252   2,489,524,820
# 2021-11  ...   4,167,818,891   3,093,419,795   2,361,626,618
# 2021-12  ...   4,581,970,971   3,471,242,070   2,597,105,443
#
#           한국_수출금액_lag12m  한국의대중국수출_lag12m  한국의대미국수출_lag12m  한국의대베트남수출_lag12m  \
# 2001-01  12,162,424,632    1,235,215,271    2,609,787,984       109,742,698
# 2001-02  12,676,042,304    1,273,117,309    2,554,309,883       112,395,157
# 2001-03  14,429,703,086    1,437,377,223    2,946,820,669       150,134,562
# 2001-04  13,522,040,017    1,366,876,604    2,698,029,849       169,146,208
# 2001-05  14,636,754,971    1,663,240,667    3,167,181,403       169,411,680
# ...                  ...              ...              ...               ...
# 2021-08  39,469,230,580   10,937,537,712    5,581,925,095     4,107,144,926
# 2021-09  47,819,947,522   12,185,274,325    6,997,553,830     4,796,012,203
# 2021-10  44,818,534,427   11,527,355,549    6,562,208,994     4,508,943,206
# 2021-11  45,751,883,232   12,029,854,423    6,664,272,439     4,506,085,066
# 2021-12  51,332,449,396   12,710,301,396    7,157,647,338     5,242,213,207
#
#          한국의대홍콩수출_lag12m 한국의대일본수출_lag12m          한국 수출금액
# 2001-01     782,348,732   1,551,722,070   12,644,929,017
# 2001-02     823,990,122   1,518,844,843   13,354,073,762
# 2001-03     911,648,256   1,783,564,618   14,124,891,326
# 2001-04     863,243,219   1,582,707,525   12,121,109,771
# 2001-05     887,081,090   1,671,039,709   13,306,959,164
# ...                  ...             ...              ...
# 2021-08   2,150,968,919   1,761,392,723   53,165,103,786
# 2021-09   3,005,224,076   2,156,620,830   55,913,862,375
# 2021-10   2,731,820,714   1,924,047,355   55,660,372,637
# 2021-11   2,635,980,263   2,122,869,801   60,330,542,263
# 2021-12   3,102,676,601   2,332,172,653   60,734,116,670
#
# [252 rows x 56 columns]

# %%
def to_f(str):
   return float(str.replace(',', ''))

df = df.applymap(str)
df = df.applymap(to_f)

# %%
df.isnull().sum()
# Out:
# 산업생산지수_lag_6                  0
# 일본_산업생산지수_lag_6               0
# 미국_산업생산지수_lag_6               0
# 선행종합지수_lag_6                  0
# 기업경기실사지수_lag6                31
# 미국_환율_lag6                    0
# 중국_환율_lag6                    0
# 일본_환율_lag6                    0
# CD_lag6                       0
# 회사채                          25
# 생산자물가지수_lag6                  0
# 원재료물가지수_lag6                  0
# 중간재물가지수_lag6                  0
# 최종재물가지수_lag6                  0
# 소비자물가지수_lag6                  0
# 중국_소비자물가지수_lag6               0
# 일본_소비자물가지수_lag6               0
# 미국_소비자물가지수_lag6               0
# 국내총생산_lag                     0
# 국내총소득_lag                     0
# KOSPI_lag6                    0
# DowJones_lag6                 0
# NIKKEI_lag6                   0
# SHCOMP_lag6                   0
# P_WTI_lag6                    0
# P_Dubai_lag6                  0
# P_Brent_lag6                  0
# P_금_lag6                      0
# 경제심리지수_lag6                  36
# 뉴스심리지수_lag6                  54
# 수출물가_lag6                     0
# 수출물가_lag12                    0
# WTI유가_lag6                    0
# WTI유가_lag12                   0
# 중국_실질실효환율_lag6     0
# 일본_실질실효환율_lag6     0
# 미국_실질실효환율_lag6     0
# 한국_실질실효환율_lag6     0
# 수출건수_lag6                     0
# 수출건수_lag12                    0
# 한국_환율_lag6                    0
# 한국_환율_lag12                   0
# 경제성장률_lag6                    0
# 한국_수출금액_lag6m                 0
# 한국의대중국수출_lag6m                0
# 한국의대미국수출_lag6m                0
# 한국의대베트남수출_lag6m               0
# 한국의대홍콩수출_lag6m                0
# 한국의대일본수출_lag6m                0
# 한국_수출금액_lag12m                0
# 한국의대중국수출_lag12m               0
# 한국의대미국수출_lag12m               0
# 한국의대베트남수출_lag12m              0
# 한국의대홍콩수출_lag12m               0
# 한국의대일본수출_lag12m               0
# 한국 수출금액                       0
# dtype: int64

# %% [markdown]
# # train/val 데이터 split

# %%
from lightgbm import LGBMClassifier
import lightgbm as lgb
from sklearn.metrics import mean_squared_error

import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
target = df['한국 수출금액']
data = df.drop('한국 수출금액', axis=1)

# %%
target
# Out:
# 2001-01    1.264493e+10
# 2001-02    1.335407e+10
# 2001-03    1.412489e+10
# 2001-04    1.212111e+10
# 2001-05    1.330696e+10
#                ...
# 2021-08    5.316510e+10
# 2021-09    5.591386e+10
# 2021-10    5.566037e+10
# 2021-11    6.033054e+10
# 2021-12    6.073412e+10
# Name: 한국 수출금액, Length: 252, dtype: float64

# %%
X_train = data.iloc[:246]
y_train = target.iloc[:246]
X_val = data.iloc[246:]
y_val = target.iloc[246:]

# %% [markdown]
# # LGBM Model

# %%
model = lgb.LGBMRegressor(random_state=42)
model.fit(
    X_train,
    y_train,
    eval_set=[(X_train, y_train),(X_val, y_val)],
    eval_metric='rmse'
    )
y_pred = model.predict(X_val)
# Out:
# [1]	training's l2: 1.29558e+20	training's rmse: 1.13824e+10	valid_1's l2: 3.99254e+20	valid_1's rmse: 1.99813e+10
# [2]	training's l2: 1.06511e+20	training's rmse: 1.03204e+10	valid_1's l2: 3.56665e+20	valid_1's rmse: 1.88856e+10
# [3]	training's l2: 8.77139e+19	training's rmse: 9.36557e+09	valid_1's l2: 3.16209e+20	valid_1's rmse: 1.77823e+10
# [4]	training's l2: 7.23853e+19	training's rmse: 8.50796e+09	valid_1's l2: 2.85373e+20	valid_1's rmse: 1.6893e+10
# [5]	training's l2: 5.9971e+19	training's rmse: 7.74409e+09	valid_1's l2: 2.557e+20	valid_1's rmse: 1.59906e+10
# [6]	training's l2: 4.97834e+19	training's rmse: 7.05573e+09	valid_1's l2: 2.34525e+20	valid_1's rmse: 1.53142e+10
# [7]	training's l2: 4.14279e+19	training's rmse: 6.43645e+09	valid_1's l2: 2.10671e+20	valid_1's rmse: 1.45145e+10
# [8]	training's l2: 3.46535e+19	training's rmse: 5.88672e+09	valid_1's l2: 1.9209e+20	valid_1's rmse: 1.38597e+10
# [9]	training's l2: 2.90998e+19	training's rmse: 5.39442e+09	valid_1's l2: 1.75899e+20	valid_1's rmse: 1.32627e+10
# [10]	training's l2: 2.45559e+19	training's rmse: 4.95539e+09	valid_1's l2: 1.62834e+20	valid_1's rmse: 1.27606e+10
# [11]	training's l2: 2.07609e+19	training's rmse: 4.55641e+09	valid_1's l2: 1.52067e+20	valid_1's rmse: 1.23315e+10
# [12]	training's l2: 1.76964e+19	training's rmse: 4.2067e+09	valid_1's l2: 1.40234e+20	valid_1's rmse: 1.1842e+10
# [13]	training's l2: 1.50921e+19	training's rmse: 3.88486e+09	valid_1's l2: 1.29655e+20	valid_1's rmse: 1.13866e+10
# [14]	training's l2: 1.30286e+19	training's rmse: 3.60952e+09	valid_1's l2: 1.20756e+20	valid_1's rmse: 1.09889e+10
# [15]	training's l2: 1.12831e+19	training's rmse: 3.35903e+09	valid_1's l2: 1.12057e+20	valid_1's rmse: 1.05857e+10
# [16]	training's l2: 9.80439e+18	training's rmse: 3.1312e+09	valid_1's l2: 1.05567e+20	valid_1's rmse: 1.02746e+10
# [17]	training's l2: 8.63639e+18	training's rmse: 2.93877e+09	valid_1's l2: 1.00229e+20	valid_1's rmse: 1.00114e+10
# [18]	training's l2: 7.65288e+18	training's rmse: 2.76638e+09	valid_1's l2: 9.52504e+19	valid_1's rmse: 9.75963e+09
# [19]	training's l2: 6.77284e+18	training's rmse: 2.60247e+09	valid_1's l2: 8.97025e+19	valid_1's rmse: 9.47114e+09
# [20]	training's l2: 6.08609e+18	training's rmse: 2.467e+09	valid_1's l2: 8.64859e+19	valid_1's rmse: 9.29978e+09
# [21]	training's l2: 5.48114e+18	training's rmse: 2.34118e+09	valid_1's l2: 8.087e+19	valid_1's rmse: 8.99278e+09
# [22]	training's l2: 4.96144e+18	training's rmse: 2.22743e+09	valid_1's l2: 7.98713e+19	valid_1's rmse: 8.93708e+09
# [23]	training's l2: 4.52799e+18	training's rmse: 2.12791e+09	valid_1's l2: 7.65501e+19	valid_1's rmse: 8.74929e+09
# [24]	training's l2: 4.12093e+18	training's rmse: 2.03001e+09	valid_1's l2: 7.41408e+19	valid_1's rmse: 8.6105e+09
# [25]	training's l2: 3.7914e+18	training's rmse: 1.94715e+09	valid_1's l2: 7.35911e+19	valid_1's rmse: 8.57853e+09
# [26]	training's l2: 3.53831e+18	training's rmse: 1.88104e+09	valid_1's l2: 7.26925e+19	valid_1's rmse: 8.52599e+09
# [27]	training's l2: 3.32296e+18	training's rmse: 1.8229e+09	valid_1's l2: 7.05418e+19	valid_1's rmse: 8.39891e+09
# [28]	training's l2: 3.08062e+18	training's rmse: 1.75517e+09	valid_1's l2: 6.95014e+19	valid_1's rmse: 8.33675e+09
# [29]	training's l2: 2.88933e+18	training's rmse: 1.6998e+09	valid_1's l2: 6.71521e+19	valid_1's rmse: 8.19464e+09
# [30]	training's l2: 2.70871e+18	training's rmse: 1.64582e+09	valid_1's l2: 6.50914e+19	valid_1's rmse: 8.06792e+09
# [31]	training's l2: 2.5774e+18	training's rmse: 1.60543e+09	valid_1's l2: 6.43429e+19	valid_1's rmse: 8.0214e+09
# [32]	training's l2: 2.44577e+18	training's rmse: 1.5639e+09	valid_1's l2: 6.23599e+19	valid_1's rmse: 7.89683e+09
# [33]	training's l2: 2.32341e+18	training's rmse: 1.52428e+09	valid_1's l2: 6.05487e+19	valid_1's rmse: 7.7813e+09
# [34]	training's l2: 2.2217e+18	training's rmse: 1.49054e+09	valid_1's l2: 5.88827e+19	valid_1's rmse: 7.67351e+09
# [35]	training's l2: 2.12197e+18	training's rmse: 1.4567e+09	valid_1's l2: 5.76014e+19	valid_1's rmse: 7.58956e+09
# [36]	training's l2: 2.02428e+18	training's rmse: 1.42277e+09	valid_1's l2: 5.74347e+19	valid_1's rmse: 7.57857e+09
# [37]	training's l2: 1.94026e+18	training's rmse: 1.39293e+09	valid_1's l2: 5.59363e+19	valid_1's rmse: 7.47906e+09
# [38]	training's l2: 1.86116e+18	training's rmse: 1.36424e+09	valid_1's l2: 5.4512e+19	valid_1's rmse: 7.38323e+09
# [39]	training's l2: 1.80003e+18	training's rmse: 1.34165e+09	valid_1's l2: 5.36171e+19	valid_1's rmse: 7.32237e+09
# [40]	training's l2: 1.73244e+18	training's rmse: 1.31622e+09	valid_1's l2: 5.42685e+19	valid_1's rmse: 7.36671e+09
# [41]	training's l2: 1.66173e+18	training's rmse: 1.28908e+09	valid_1's l2: 5.32196e+19	valid_1's rmse: 7.29518e+09
# [42]	training's l2: 1.61646e+18	training's rmse: 1.2714e+09	valid_1's l2: 5.22587e+19	valid_1's rmse: 7.22902e+09
# [43]	training's l2: 1.56701e+18	training's rmse: 1.2518e+09	valid_1's l2: 5.15941e+19	valid_1's rmse: 7.1829e+09
# [44]	training's l2: 1.51515e+18	training's rmse: 1.23091e+09	valid_1's l2: 5.03056e+19	valid_1's rmse: 7.09264e+09
# [45]	training's l2: 1.47835e+18	training's rmse: 1.21587e+09	valid_1's l2: 5.07195e+19	valid_1's rmse: 7.12176e+09
# [46]	training's l2: 1.44055e+18	training's rmse: 1.20023e+09	valid_1's l2: 4.95443e+19	valid_1's rmse: 7.03877e+09
# [47]	training's l2: 1.40074e+18	training's rmse: 1.18353e+09	valid_1's l2: 4.97487e+19	valid_1's rmse: 7.05328e+09
# [48]	training's l2: 1.35102e+18	training's rmse: 1.16233e+09	valid_1's l2: 5.01908e+19	valid_1's rmse: 7.08455e+09
# [49]	training's l2: 1.31226e+18	training's rmse: 1.14554e+09	valid_1's l2: 4.97359e+19	valid_1's rmse: 7.05237e+09
# [50]	training's l2: 1.27284e+18	training's rmse: 1.1282e+09	valid_1's l2: 5.01535e+19	valid_1's rmse: 7.08192e+09
# [51]	training's l2: 1.24017e+18	training's rmse: 1.11363e+09	valid_1's l2: 4.97526e+19	valid_1's rmse: 7.05355e+09
# [52]	training's l2: 1.20435e+18	training's rmse: 1.09743e+09	valid_1's l2: 4.9648e+19	valid_1's rmse: 7.04614e+09
# [53]	training's l2: 1.16748e+18	training's rmse: 1.0805e+09	valid_1's l2: 5.0129e+19	valid_1's rmse: 7.08018e+09
# [54]	training's l2: 1.13875e+18	training's rmse: 1.06712e+09	valid_1's l2: 5.03189e+19	valid_1's rmse: 7.09358e+09
# [55]	training's l2: 1.11321e+18	training's rmse: 1.05509e+09	valid_1's l2: 4.99667e+19	valid_1's rmse: 7.06871e+09
# [56]	training's l2: 1.0839e+18	training's rmse: 1.04111e+09	valid_1's l2: 4.98057e+19	valid_1's rmse: 7.05732e+09
# [57]	training's l2: 1.06044e+18	training's rmse: 1.02978e+09	valid_1's l2: 4.95843e+19	valid_1's rmse: 7.04161e+09
# [58]	training's l2: 1.03115e+18	training's rmse: 1.01546e+09	valid_1's l2: 4.95497e+19	valid_1's rmse: 7.03915e+09
# [59]	training's l2: 1.01245e+18	training's rmse: 1.00621e+09	valid_1's l2: 4.92305e+19	valid_1's rmse: 7.01644e+09
# [60]	training's l2: 9.89405e+17	training's rmse: 9.94688e+08	valid_1's l2: 4.9809e+19	valid_1's rmse: 7.05755e+09
# [61]	training's l2: 9.64713e+17	training's rmse: 9.82198e+08	valid_1's l2: 4.95033e+19	valid_1's rmse: 7.03586e+09
# [62]	training's l2: 9.48568e+17	training's rmse: 9.73944e+08	valid_1's l2: 4.94414e+19	valid_1's rmse: 7.03146e+09
# [63]	training's l2: 9.32194e+17	training's rmse: 9.65502e+08	valid_1's l2: 4.91564e+19	valid_1's rmse: 7.01116e+09
# [64]	training's l2: 9.15817e+17	training's rmse: 9.56983e+08	valid_1's l2: 4.9489e+19	valid_1's rmse: 7.03484e+09
# [65]	training's l2: 9.01187e+17	training's rmse: 9.49309e+08	valid_1's l2: 4.9275e+19	valid_1's rmse: 7.01962e+09
# [66]	training's l2: 8.8411e+17	training's rmse: 9.40271e+08	valid_1's l2: 4.88998e+19	valid_1's rmse: 6.99284e+09
# [67]	training's l2: 8.6305e+17	training's rmse: 9.29005e+08	valid_1's l2: 4.88265e+19	valid_1's rmse: 6.98759e+09
# [68]	training's l2: 8.49665e+17	training's rmse: 9.21773e+08	valid_1's l2: 4.84782e+19	valid_1's rmse: 6.96263e+09
# [69]	training's l2: 8.31794e+17	training's rmse: 9.12027e+08	valid_1's l2: 4.838e+19	valid_1's rmse: 6.95557e+09
# [70]	training's l2: 8.16143e+17	training's rmse: 9.03406e+08	valid_1's l2: 4.8073e+19	valid_1's rmse: 6.93347e+09
# [71]	training's l2: 7.96126e+17	training's rmse: 8.92259e+08	valid_1's l2: 4.77294e+19	valid_1's rmse: 6.90865e+09
# [72]	training's l2: 7.84622e+17	training's rmse: 8.85789e+08	valid_1's l2: 4.75139e+19	valid_1's rmse: 6.89303e+09
# [73]	training's l2: 7.6686e+17	training's rmse: 8.75705e+08	valid_1's l2: 4.68458e+19	valid_1's rmse: 6.8444e+09
# [74]	training's l2: 7.49227e+17	training's rmse: 8.65579e+08	valid_1's l2: 4.70136e+19	valid_1's rmse: 6.85665e+09
# [75]	training's l2: 7.3312e+17	training's rmse: 8.56224e+08	valid_1's l2: 4.67039e+19	valid_1's rmse: 6.83403e+09
# [76]	training's l2: 7.12728e+17	training's rmse: 8.44232e+08	valid_1's l2: 4.64949e+19	valid_1's rmse: 6.81872e+09
# [77]	training's l2: 7.01866e+17	training's rmse: 8.37775e+08	valid_1's l2: 4.65822e+19	valid_1's rmse: 6.82512e+09
# [78]	training's l2: 6.91841e+17	training's rmse: 8.3177e+08	valid_1's l2: 4.66622e+19	valid_1's rmse: 6.83098e+09
# [79]	training's l2: 6.76973e+17	training's rmse: 8.22784e+08	valid_1's l2: 4.61891e+19	valid_1's rmse: 6.79626e+09
# [80]	training's l2: 6.64865e+17	training's rmse: 8.15392e+08	valid_1's l2: 4.6396e+19	valid_1's rmse: 6.81146e+09
# [81]	training's l2: 6.53603e+17	training's rmse: 8.08457e+08	valid_1's l2: 4.61693e+19	valid_1's rmse: 6.7948e+09
# [82]	training's l2: 6.43222e+17	training's rmse: 8.02011e+08	valid_1's l2: 4.59371e+19	valid_1's rmse: 6.77769e+09
# [83]	training's l2: 6.31842e+17	training's rmse: 7.94885e+08	valid_1's l2: 4.56613e+19	valid_1's rmse: 6.75731e+09
# [84]	training's l2: 6.20317e+17	training's rmse: 7.87602e+08	valid_1's l2: 4.58981e+19	valid_1's rmse: 6.77481e+09
# [85]	training's l2: 6.11418e+17	training's rmse: 7.81932e+08	valid_1's l2: 4.56544e+19	valid_1's rmse: 6.7568e+09
# [86]	training's l2: 5.99664e+17	training's rmse: 7.7438e+08	valid_1's l2: 4.54375e+19	valid_1's rmse: 6.74073e+09
# [87]	training's l2: 5.90402e+17	training's rmse: 7.68377e+08	valid_1's l2: 4.51714e+19	valid_1's rmse: 6.72096e+09
# [88]	training's l2: 5.76912e+17	training's rmse: 7.59547e+08	valid_1's l2: 4.45042e+19	valid_1's rmse: 6.67115e+09
# [89]	training's l2: 5.67969e+17	training's rmse: 7.53637e+08	valid_1's l2: 4.47432e+19	valid_1's rmse: 6.68903e+09
# [90]	training's l2: 5.60307e+17	training's rmse: 7.48537e+08	valid_1's l2: 4.48206e+19	valid_1's rmse: 6.69482e+09
# [91]	training's l2: 5.52073e+17	training's rmse: 7.43016e+08	valid_1's l2: 4.50321e+19	valid_1's rmse: 6.7106e+09
# [92]	training's l2: 5.43425e+17	training's rmse: 7.37174e+08	valid_1's l2: 4.47667e+19	valid_1's rmse: 6.69079e+09
# [93]	training's l2: 5.34222e+17	training's rmse: 7.30905e+08	valid_1's l2: 4.4572e+19	valid_1's rmse: 6.67623e+09
# [94]	training's l2: 5.26771e+17	training's rmse: 7.2579e+08	valid_1's l2: 4.47714e+19	valid_1's rmse: 6.69114e+09
# [95]	training's l2: 5.20727e+17	training's rmse: 7.21614e+08	valid_1's l2: 4.45554e+19	valid_1's rmse: 6.67499e+09
# [96]	training's l2: 5.08218e+17	training's rmse: 7.12894e+08	valid_1's l2: 4.39449e+19	valid_1's rmse: 6.6291e+09
# [97]	training's l2: 4.99915e+17	training's rmse: 7.07046e+08	valid_1's l2: 4.37411e+19	valid_1's rmse: 6.61371e+09
# [98]	training's l2: 4.92427e+17	training's rmse: 7.01732e+08	valid_1's l2: 4.39381e+19	valid_1's rmse: 6.62858e+09
# [99]	training's l2: 4.81621e+17	training's rmse: 6.93989e+08	valid_1's l2: 4.33778e+19	valid_1's rmse: 6.58618e+09
# [100]	training's l2: 4.69144e+17	training's rmse: 6.84941e+08	valid_1's l2: 4.31827e+19	valid_1's rmse: 6.57136e+09

# %%
rmse = np.sqrt(mean_squared_error(y_val, y_pred))

# %%
rmse
# Out:
# 6571357822.8676195

# %%
rmse(y_val, y_pred)
# Out:
# 4.318274363616346e+19

# %% [markdown]
# # 하이퍼파라미터 튜닝

# %%
import lightgbm as lgb
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error as rmse
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## RandomizedSearchCV 사용

# %%
# 기본 모델
pipe = make_pipeline(
    lgb.LGBMRegressor(random_state=42, max_depth=7)
)

pipe.fit(X_train, y_train)

y_pred_train = pipe.predict(X_train)
y_pred_val = pipe.predict(X_val)

print('훈련 점수: ', rmse(y_train, y_pred_train))
print('검증 점수: ', rmse(y_val, y_pred_val))

# %%
# RandomizedSearchCV
pipe = make_pipeline(
    SimpleImputer(),
    StandardScaler(),
    lgb.LGBMRegressor(random_state=2, n_jobs=-1))

dists = {
    'simpleimputer__strategy': ['mean', 'median','most_frequent'],
    'lgbmregressor__learning_rate' : [0.05, 0.10,0.15,0.20,0.25], 
    'lgbmregressor__num_leaves' : [20, 40, 60, 80, 100],
    'lgbmregressor__min_child_samples' : [5, 10, 15, 20],
    'lgbmregressor__max_depth': [5, 10, 15, 20, None],
    'lgbmregressor__n_estimators' : [50, 100, 500, 1000],
    'lgbmregressor__reg_alpha' : [0, 0.01, 0.02, 0.03]
    }

clf = RandomizedSearchCV(
    pipe, 
    param_distributions=dists, 
    n_iter=10, 
    cv=5, 
    scoring='neg_root_mean_squared_error',  
    verbose=1,
    n_jobs=-1
)

clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                                              ('standardscaler',
#                                               StandardScaler()),
#                                              ('lgbmregressor',
#                                               LGBMRegressor(random_state=2))]),
#                    n_jobs=-1,
#                    param_distributions={'lgbmregressor__learning_rate': [0.05,
#                                                                          0.1,
#                                                                          0.15,
#                                                                          0.2,
#                                                                          0.25],
#                                         'lgbmregressor__max_depth': [5, 10, 15,
#                                                                      20, None],
#                                         'lgbmregressor__min_child_samples': [5,
#                                                                              10,
#                                                                              15,
#                                                                              20],
#                                         'lgbmregressor__n_estimators': [50, 100,
#                                                                         500,
#                                                                         1000],
#                                         'lgbmregressor__num_leaves': [20, 40,
#                                                                       60, 80,
#                                                                       100],
#                                         'lgbmregressor__reg_alpha': [0, 0.01,
#                                                                      0.02,
#                                                                      0.03],
#                                         'simpleimputer__strategy': ['mean',
#                                                                     'median',
#                                                                     'most_frequent']},
#                    scoring='neg_root_mean_squared_error', verbose=1)

# %%
print("최적 하이퍼파라미터 : ", clf.best_params_)
print('rmse: ', clf.best_score_)
# Out:
# 최적 하이퍼파라미터 :  {'simpleimputer__strategy': 'median', 'lgbmregressor__reg_alpha': 0.01, 'lgbmregressor__num_leaves': 40, 'lgbmregressor__n_estimators': 500, 'lgbmregressor__min_child_samples': 15, 'lgbmregressor__max_depth': 15, 'lgbmregressor__learning_rate': 0.1}
# rmse:  -5968047389.505996

# %%
y_pred_train = clf.predict(X_train)
y_pred_val = clf.predict(X_val)
print('훈련 점수: ', rmse(y_train, y_pred_train))
print('검증 점수: ', rmse(y_val, y_pred_val))
# Out:
# 훈련 점수:  372265039376302.0
# 검증 점수:  3.1982561531105554e+19

# %% [markdown]
# - 과적합 .....?! ㅠㅠ

# %% [markdown]
# ## GridSearchCV

# %%
# GridSearchCV
pipe = make_pipeline(
    SimpleImputer(),
    StandardScaler(),
    lgb.LGBMRegressor(random_state=2, n_jobs=-1))

dists = {
    'simpleimputer__strategy': ['mean', 'median','most_frequent'],
    'lgbmregressor__learning_rate' : [0.05, 0.10,0.15,0.20,0.25], 
    'lgbmregressor__num_leaves' : [20, 40, 60, 80, 100],
    'lgbmregressor__min_child_samples' : [5, 10, 15, 20],
    'lgbmregressor__max_depth': [5, 10, 15, 20, None],
    'lgbmregressor__n_estimators' : [50, 100, 500, 1000],
    'lgbmregressor__reg_alpha' : [0, 0.01, 0.02, 0.03]
    }

clf = GridSearchCV(
    pipe, 
    param_grid=dists, 
    cv=2, 
    scoring='neg_root_mean_squared_error',  
    verbose=1,
    n_jobs=-1
)

clf.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 24000 candidates, totalling 48000 fits
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                                        ('standardscaler', StandardScaler()),
#                                        ('lgbmregressor',
#                                         LGBMRegressor(random_state=2))]),
#              n_jobs=-1,
#              param_grid={'lgbmregressor__learning_rate': [0.05, 0.1, 0.15, 0.2,
#                                                           0.25],
#                          'lgbmregressor__max_depth': [5, 10, 15, 20, None],
#                          'lgbmregressor__min_child_samples': [5, 10, 15, 20],
#                          'lgbmregressor__n_estimators': [50, 100, 500, 1000],
#                          'lgbmregressor__num_leaves': [20, 40, 60, 80, 100],
#                          'lgbmregressor__reg_alpha': [0, 0.01, 0.02, 0.03],
#                          'simpleimputer__strategy': ['mean', 'median',
#                                                      'most_frequent']},
#              scoring='neg_root_mean_squared_error', verbose=1)

# %%
print("최적 하이퍼파라미터 : ", clf.best_params_)
print('rmse: ', clf.best_score_)
# Out:
# 최적 하이퍼파라미터 :  {'lgbmregressor__learning_rate': 0.2, 'lgbmregressor__max_depth': 10, 'lgbmregressor__min_child_samples': 5, 'lgbmregressor__n_estimators': 1000, 'lgbmregressor__num_leaves': 40, 'lgbmregressor__reg_alpha': 0.01, 'simpleimputer__strategy': 'most_frequent'}
# rmse:  -12013191016.470768

# %%
y_pred_train = clf.predict(X_train)
y_pred_val = clf.predict(X_val)
print('훈련 점수: ', rmse(y_train, y_pred_train))
print('검증 점수: ', rmse(y_val, y_pred_val))
# Out:
# 훈련 점수:  934691.2818673621
# 검증 점수:  5.146544220515229e+19

# %% [markdown]
# ## Early Stopping 사용

# %%
scaler = StandardScaler()
imputer = SimpleImputer(strategy='mean')

X_train_imputed = imputer.fit_transform(X_train, y_train) # 학습데이터
X_val_imputed = imputer.transform(X_val) # 검증데이터

X_train_scaled = scaler.fit_transform(X_train_imputed)
X_val_scaled = scaler.transform(X_val_imputed)

model = lgb.LGBMRegressor(
    reg_alpha = 0.01,
    num_leaves = 40,
    min_child_samples = 15,
    max_depth = 15, 
    learning_rate = 0.1,
    n_estimators = 5000,
    n_jobs=-1)

eval_set = [(X_train_scaled, y_train), 
            (X_val_scaled, y_val)]

model.fit(X_train_scaled, y_train, 
          eval_set=eval_set,
          early_stopping_rounds=500,
          eval_metric="rmse",
          verbose=True
         )
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [3]	training's rmse: 9.31625e+09	training's l2: 8.67924e+19	valid_1's rmse: 1.73185e+10	valid_1's l2: 2.99931e+20
# [4]	training's rmse: 8.44645e+09	training's l2: 7.13425e+19	valid_1's rmse: 1.62426e+10	valid_1's l2: 2.63823e+20
# [5]	training's rmse: 7.65476e+09	training's l2: 5.85954e+19	valid_1's rmse: 1.52761e+10	valid_1's l2: 2.33359e+20
# [6]	training's rmse: 6.94399e+09	training's l2: 4.8219e+19	valid_1's rmse: 1.43548e+10	valid_1's l2: 2.0606e+20
# [7]	training's rmse: 6.31416e+09	training's l2: 3.98686e+19	valid_1's rmse: 1.35703e+10	valid_1's l2: 1.84153e+20
# [8]	training's rmse: 5.74659e+09	training's l2: 3.30233e+19	valid_1's rmse: 1.28659e+10	valid_1's l2: 1.65531e+20
# [9]	training's rmse: 5.23611e+09	training's l2: 2.74169e+19	valid_1's rmse: 1.21822e+10	valid_1's l2: 1.48407e+20
# [10]	training's rmse: 4.78012e+09	training's l2: 2.28496e+19	valid_1's rmse: 1.15657e+10	valid_1's l2: 1.33766e+20
# [11]	training's rmse: 4.37337e+09	training's l2: 1.91263e+19	valid_1's rmse: 1.10511e+10	valid_1's l2: 1.22126e+20
# [12]	training's rmse: 4.00499e+09	training's l2: 1.604e+19	valid_1's rmse: 1.05494e+10	valid_1's l2: 1.1129e+20
# [13]	training's rmse: 3.68186e+09	training's l2: 1.35561e+19	valid_1's rmse: 1.01143e+10	valid_1's l2: 1.023e+20
# [14]	training's rmse: 3.39482e+09	training's l2: 1.15248e+19	valid_1's rmse: 9.72393e+09	valid_1's l2: 9.45549e+19
# [15]	training's rmse: 3.1271e+09	training's l2: 9.77878e+18	valid_1's rmse: 9.58619e+09	valid_1's l2: 9.1895e+19
# [16]	training's rmse: 2.89278e+09	training's l2: 8.36815e+18	valid_1's rmse: 9.26612e+09	valid_1's l2: 8.5861e+19
# [17]	training's rmse: 2.68406e+09	training's l2: 7.20417e+18	valid_1's rmse: 8.9485e+09	valid_1's l2: 8.00756e+19
# [18]	training's rmse: 2.50105e+09	training's l2: 6.25523e+18	valid_1's rmse: 8.73026e+09	valid_1's l2: 7.62174e+19
# [19]	training's rmse: 2.33728e+09	training's l2: 5.46287e+18	valid_1's rmse: 8.47774e+09	valid_1's l2: 7.18721e+19
# [20]	training's rmse: 2.19186e+09	training's l2: 4.80426e+18	valid_1's rmse: 8.40383e+09	valid_1's l2: 7.06243e+19
# [21]	training's rmse: 2.06545e+09	training's l2: 4.26607e+18	valid_1's rmse: 8.24391e+09	valid_1's l2: 6.79621e+19
# [22]	training's rmse: 1.95648e+09	training's l2: 3.82783e+18	valid_1's rmse: 8.04547e+09	valid_1's l2: 6.47297e+19
# [23]	training's rmse: 1.86458e+09	training's l2: 3.47666e+18	valid_1's rmse: 7.84858e+09	valid_1's l2: 6.16002e+19
# [24]	training's rmse: 1.771e+09	training's l2: 3.13645e+18	valid_1's rmse: 7.83117e+09	valid_1's l2: 6.13272e+19
# [25]	training's rmse: 1.69391e+09	training's l2: 2.86935e+18	valid_1's rmse: 7.66531e+09	valid_1's l2: 5.8757e+19
# [26]	training's rmse: 1.61517e+09	training's l2: 2.60878e+18	valid_1's rmse: 7.5606e+09	valid_1's l2: 5.71627e+19
# [27]	training's rmse: 1.55007e+09	training's l2: 2.40271e+18	valid_1's rmse: 7.4288e+09	valid_1's l2: 5.51871e+19
# [28]	training's rmse: 1.48622e+09	training's l2: 2.20885e+18	valid_1's rmse: 7.37993e+09	valid_1's l2: 5.44634e+19
# [29]	training's rmse: 1.43011e+09	training's l2: 2.04521e+18	valid_1's rmse: 7.24506e+09	valid_1's l2: 5.24909e+19
# [30]	training's rmse: 1.37792e+09	training's l2: 1.89866e+18	valid_1's rmse: 7.22457e+09	valid_1's l2: 5.21944e+19
# [31]	training's rmse: 1.33231e+09	training's l2: 1.77504e+18	valid_1's rmse: 7.15078e+09	valid_1's l2: 5.11336e+19
# [32]	training's rmse: 1.29281e+09	training's l2: 1.67136e+18	valid_1's rmse: 7.14339e+09	valid_1's l2: 5.1028e+19
# [33]	training's rmse: 1.25361e+09	training's l2: 1.57153e+18	valid_1's rmse: 7.01633e+09	valid_1's l2: 4.92289e+19
# [34]	training's rmse: 1.22125e+09	training's l2: 1.49146e+18	valid_1's rmse: 6.93241e+09	valid_1's l2: 4.80583e+19
# [35]	training's rmse: 1.19192e+09	training's l2: 1.42067e+18	valid_1's rmse: 6.88215e+09	valid_1's l2: 4.73639e+19
# [36]	training's rmse: 1.1582e+09	training's l2: 1.34142e+18	valid_1's rmse: 6.82158e+09	valid_1's l2: 4.6534e+19
# [37]	training's rmse: 1.12826e+09	training's l2: 1.27297e+18	valid_1's rmse: 6.74226e+09	valid_1's l2: 4.54581e+19
# [38]	training's rmse: 1.09993e+09	training's l2: 1.20985e+18	valid_1's rmse: 6.67215e+09	valid_1's l2: 4.45177e+19
# [39]	training's rmse: 1.07429e+09	training's l2: 1.1541e+18	valid_1's rmse: 6.66121e+09	valid_1's l2: 4.43717e+19
# [40]	training's rmse: 1.05139e+09	training's l2: 1.10542e+18	valid_1's rmse: 6.60368e+09	valid_1's l2: 4.36086e+19
# [41]	training's rmse: 1.02925e+09	training's l2: 1.05936e+18	valid_1's rmse: 6.55263e+09	valid_1's l2: 4.2937e+19
# [42]	training's rmse: 1.00482e+09	training's l2: 1.00966e+18	valid_1's rmse: 6.4876e+09	valid_1's l2: 4.2089e+19
# [43]	training's rmse: 9.86943e+08	training's l2: 9.74057e+17	valid_1's rmse: 6.43357e+09	valid_1's l2: 4.13909e+19
# [44]	training's rmse: 9.68623e+08	training's l2: 9.3823e+17	valid_1's rmse: 6.38618e+09	valid_1's l2: 4.07833e+19
# [45]	training's rmse: 9.49149e+08	training's l2: 9.00884e+17	valid_1's rmse: 6.32723e+09	valid_1's l2: 4.00339e+19
# [46]	training's rmse: 9.30405e+08	training's l2: 8.65653e+17	valid_1's rmse: 6.28246e+09	valid_1's l2: 3.94693e+19
# [47]	training's rmse: 9.16987e+08	training's l2: 8.40864e+17	valid_1's rmse: 6.2422e+09	valid_1's l2: 3.8965e+19
# [48]	training's rmse: 8.96723e+08	training's l2: 8.04112e+17	valid_1's rmse: 6.19e+09	valid_1's l2: 3.8316e+19
# [49]	training's rmse: 8.82797e+08	training's l2: 7.7933e+17	valid_1's rmse: 6.15389e+09	valid_1's l2: 3.78704e+19
# [50]	training's rmse: 8.72254e+08	training's l2: 7.60827e+17	valid_1's rmse: 6.11637e+09	valid_1's l2: 3.741e+19
# [51]	training's rmse: 8.56512e+08	training's l2: 7.33613e+17	valid_1's rmse: 6.05687e+09	valid_1's l2: 3.66857e+19
# [52]	training's rmse: 8.42359e+08	training's l2: 7.09569e+17	valid_1's rmse: 6.10219e+09	valid_1's l2: 3.72367e+19
# [53]	training's rmse: 8.27932e+08	training's l2: 6.85471e+17	valid_1's rmse: 6.05944e+09	valid_1's l2: 3.67168e+19
# [54]	training's rmse: 8.16682e+08	training's l2: 6.66969e+17	valid_1's rmse: 6.03033e+09	valid_1's l2: 3.63649e+19
# [55]	training's rmse: 8.03366e+08	training's l2: 6.45397e+17	valid_1's rmse: 5.97477e+09	valid_1's l2: 3.56978e+19
# [56]	training's rmse: 7.92043e+08	training's l2: 6.27332e+17	valid_1's rmse: 5.9659e+09	valid_1's l2: 3.55919e+19
# [57]	training's rmse: 7.82446e+08	training's l2: 6.12222e+17	valid_1's rmse: 5.99401e+09	valid_1's l2: 3.59281e+19
# [58]	training's rmse: 7.67631e+08	training's l2: 5.89257e+17	valid_1's rmse: 5.94387e+09	valid_1's l2: 3.53296e+19
# [59]	training's rmse: 7.58029e+08	training's l2: 5.74609e+17	valid_1's rmse: 5.91991e+09	valid_1's l2: 3.50454e+19
# [60]	training's rmse: 7.45183e+08	training's l2: 5.55298e+17	valid_1's rmse: 5.89375e+09	valid_1's l2: 3.47363e+19
# [61]	training's rmse: 7.31398e+08	training's l2: 5.34943e+17	valid_1's rmse: 5.84718e+09	valid_1's l2: 3.41895e+19
# [62]	training's rmse: 7.19468e+08	training's l2: 5.17634e+17	valid_1's rmse: 5.8524e+09	valid_1's l2: 3.42505e+19
# [63]	training's rmse: 7.09897e+08	training's l2: 5.03953e+17	valid_1's rmse: 5.87884e+09	valid_1's l2: 3.45607e+19
# [64]	training's rmse: 6.96696e+08	training's l2: 4.85385e+17	valid_1's rmse: 5.87464e+09	valid_1's l2: 3.45114e+19
# [65]	training's rmse: 6.86337e+08	training's l2: 4.71058e+17	valid_1's rmse: 5.85123e+09	valid_1's l2: 3.42369e+19
# [66]	training's rmse: 6.77428e+08	training's l2: 4.58909e+17	valid_1's rmse: 5.87474e+09	valid_1's l2: 3.45125e+19
# [67]	training's rmse: 6.66858e+08	training's l2: 4.447e+17	valid_1's rmse: 5.8383e+09	valid_1's l2: 3.40858e+19
# [68]	training's rmse: 6.56568e+08	training's l2: 4.31082e+17	valid_1's rmse: 5.80528e+09	valid_1's l2: 3.37013e+19
# [69]	training's rmse: 6.45786e+08	training's l2: 4.1704e+17	valid_1's rmse: 5.84682e+09	valid_1's l2: 3.41853e+19
# [70]	training's rmse: 6.35609e+08	training's l2: 4.03999e+17	valid_1's rmse: 5.82717e+09	valid_1's l2: 3.39559e+19
# [71]	training's rmse: 6.24148e+08	training's l2: 3.89561e+17	valid_1's rmse: 5.78756e+09	valid_1's l2: 3.34958e+19
# [72]	training's rmse: 6.16713e+08	training's l2: 3.80335e+17	valid_1's rmse: 5.80753e+09	valid_1's l2: 3.37274e+19
# [73]	training's rmse: 6.0797e+08	training's l2: 3.69628e+17	valid_1's rmse: 5.81165e+09	valid_1's l2: 3.37752e+19
# [74]	training's rmse: 5.98145e+08	training's l2: 3.57778e+17	valid_1's rmse: 5.8113e+09	valid_1's l2: 3.37712e+19
# [75]	training's rmse: 5.89135e+08	training's l2: 3.47081e+17	valid_1's rmse: 5.79295e+09	valid_1's l2: 3.35583e+19
# [76]	training's rmse: 5.81123e+08	training's l2: 3.37704e+17	valid_1's rmse: 5.81138e+09	valid_1's l2: 3.37722e+19
# [77]	training's rmse: 5.72991e+08	training's l2: 3.28319e+17	valid_1's rmse: 5.78152e+09	valid_1's l2: 3.3426e+19
# [78]	training's rmse: 5.64978e+08	training's l2: 3.192e+17	valid_1's rmse: 5.79532e+09	valid_1's l2: 3.35858e+19
# [79]	training's rmse: 5.54429e+08	training's l2: 3.07392e+17	valid_1's rmse: 5.79691e+09	valid_1's l2: 3.36042e+19
# [80]	training's rmse: 5.47347e+08	training's l2: 2.99589e+17	valid_1's rmse: 5.76948e+09	valid_1's l2: 3.32869e+19
# [81]	training's rmse: 5.37592e+08	training's l2: 2.89005e+17	valid_1's rmse: 5.74479e+09	valid_1's l2: 3.30026e+19
# [82]	training's rmse: 5.30253e+08	training's l2: 2.81168e+17	valid_1's rmse: 5.72924e+09	valid_1's l2: 3.28242e+19
# [83]	training's rmse: 5.234e+08	training's l2: 2.73947e+17	valid_1's rmse: 5.74527e+09	valid_1's l2: 3.30082e+19
# [84]	training's rmse: 5.16359e+08	training's l2: 2.66626e+17	valid_1's rmse: 5.746e+09	valid_1's l2: 3.30165e+19
# [85]	training's rmse: 5.0898e+08	training's l2: 2.59061e+17	valid_1's rmse: 5.71639e+09	valid_1's l2: 3.26771e+19
# [86]	training's rmse: 5.03021e+08	training's l2: 2.5303e+17	valid_1's rmse: 5.69081e+09	valid_1's l2: 3.23853e+19
# [87]	training's rmse: 4.94902e+08	training's l2: 2.44928e+17	valid_1's rmse: 5.69001e+09	valid_1's l2: 3.23762e+19
# [88]	training's rmse: 4.89065e+08	training's l2: 2.39185e+17	valid_1's rmse: 5.70334e+09	valid_1's l2: 3.25281e+19
# [89]	training's rmse: 4.83703e+08	training's l2: 2.33969e+17	valid_1's rmse: 5.71761e+09	valid_1's l2: 3.26911e+19
# [90]	training's rmse: 4.77374e+08	training's l2: 2.27886e+17	valid_1's rmse: 5.70104e+09	valid_1's l2: 3.25018e+19
# [91]	training's rmse: 4.70045e+08	training's l2: 2.20943e+17	valid_1's rmse: 5.72526e+09	valid_1's l2: 3.27786e+19
# [92]	training's rmse: 4.64793e+08	training's l2: 2.16032e+17	valid_1's rmse: 5.71372e+09	valid_1's l2: 3.26466e+19
# [93]	training's rmse: 4.58456e+08	training's l2: 2.10182e+17	valid_1's rmse: 5.69986e+09	valid_1's l2: 3.24884e+19
# [94]	training's rmse: 4.49517e+08	training's l2: 2.02066e+17	valid_1's rmse: 5.67359e+09	valid_1's l2: 3.21896e+19
# [95]	training's rmse: 4.44738e+08	training's l2: 1.97792e+17	valid_1's rmse: 5.67269e+09	valid_1's l2: 3.21794e+19
# [96]	training's rmse: 4.402e+08	training's l2: 1.93776e+17	valid_1's rmse: 5.65979e+09	valid_1's l2: 3.20332e+19
# [97]	training's rmse: 4.35238e+08	training's l2: 1.89432e+17	valid_1's rmse: 5.67125e+09	valid_1's l2: 3.21631e+19
# [98]	training's rmse: 4.30001e+08	training's l2: 1.84901e+17	valid_1's rmse: 5.67464e+09	valid_1's l2: 3.22015e+19
# [99]	training's rmse: 4.24084e+08	training's l2: 1.79847e+17	valid_1's rmse: 5.68742e+09	valid_1's l2: 3.23467e+19
# [100]	training's rmse: 4.20298e+08	training's l2: 1.7665e+17	valid_1's rmse: 5.68365e+09	valid_1's l2: 3.23039e+19
# [101]	training's rmse: 4.15858e+08	training's l2: 1.72938e+17	valid_1's rmse: 5.66984e+09	valid_1's l2: 3.21471e+19
# [102]	training's rmse: 4.10469e+08	training's l2: 1.68485e+17	valid_1's rmse: 5.64357e+09	valid_1's l2: 3.18499e+19
# [103]	training's rmse: 4.04909e+08	training's l2: 1.63952e+17	valid_1's rmse: 5.63778e+09	valid_1's l2: 3.17845e+19
# [104]	training's rmse: 4.00558e+08	training's l2: 1.60447e+17	valid_1's rmse: 5.63632e+09	valid_1's l2: 3.17682e+19
# [105]	training's rmse: 3.96733e+08	training's l2: 1.57397e+17	valid_1's rmse: 5.62662e+09	valid_1's l2: 3.16588e+19
# [106]	training's rmse: 3.9264e+08	training's l2: 1.54166e+17	valid_1's rmse: 5.61542e+09	valid_1's l2: 3.15329e+19
# [107]	training's rmse: 3.8826e+08	training's l2: 1.50745e+17	valid_1's rmse: 5.6287e+09	valid_1's l2: 3.16823e+19
# [108]	training's rmse: 3.83903e+08	training's l2: 1.47382e+17	valid_1's rmse: 5.62424e+09	valid_1's l2: 3.16321e+19
# [109]	training's rmse: 3.79951e+08	training's l2: 1.44363e+17	valid_1's rmse: 5.63415e+09	valid_1's l2: 3.17436e+19
# [110]	training's rmse: 3.75452e+08	training's l2: 1.40964e+17	valid_1's rmse: 5.62367e+09	valid_1's l2: 3.16257e+19
# [111]	training's rmse: 3.71521e+08	training's l2: 1.38028e+17	valid_1's rmse: 5.61259e+09	valid_1's l2: 3.15012e+19
# [112]	training's rmse: 3.66165e+08	training's l2: 1.34077e+17	valid_1's rmse: 5.59703e+09	valid_1's l2: 3.13267e+19
# [113]	training's rmse: 3.60651e+08	training's l2: 1.30069e+17	valid_1's rmse: 5.59614e+09	valid_1's l2: 3.13168e+19
# [114]	training's rmse: 3.55625e+08	training's l2: 1.26469e+17	valid_1's rmse: 5.58676e+09	valid_1's l2: 3.12119e+19
# [115]	training's rmse: 3.51736e+08	training's l2: 1.23718e+17	valid_1's rmse: 5.59325e+09	valid_1's l2: 3.12845e+19
# [116]	training's rmse: 3.48681e+08	training's l2: 1.21578e+17	valid_1's rmse: 5.58504e+09	valid_1's l2: 3.11927e+19
# [117]	training's rmse: 3.45596e+08	training's l2: 1.19436e+17	valid_1's rmse: 5.58111e+09	valid_1's l2: 3.11488e+19
# [118]	training's rmse: 3.41651e+08	training's l2: 1.16726e+17	valid_1's rmse: 5.56126e+09	valid_1's l2: 3.09276e+19
# [119]	training's rmse: 3.37571e+08	training's l2: 1.13954e+17	valid_1's rmse: 5.55324e+09	valid_1's l2: 3.08384e+19
# [120]	training's rmse: 3.34017e+08	training's l2: 1.11568e+17	valid_1's rmse: 5.56189e+09	valid_1's l2: 3.09346e+19
# [121]	training's rmse: 3.30574e+08	training's l2: 1.09279e+17	valid_1's rmse: 5.55302e+09	valid_1's l2: 3.08361e+19
# [122]	training's rmse: 3.27546e+08	training's l2: 1.07286e+17	valid_1's rmse: 5.56148e+09	valid_1's l2: 3.093e+19
# [123]	training's rmse: 3.23929e+08	training's l2: 1.0493e+17	valid_1's rmse: 5.56909e+09	valid_1's l2: 3.10148e+19
# [124]	training's rmse: 3.21004e+08	training's l2: 1.03044e+17	valid_1's rmse: 5.56195e+09	valid_1's l2: 3.09353e+19
# [125]	training's rmse: 3.15788e+08	training's l2: 9.97219e+16	valid_1's rmse: 5.55302e+09	valid_1's l2: 3.0836e+19
# [126]	training's rmse: 3.12751e+08	training's l2: 9.78131e+16	valid_1's rmse: 5.56045e+09	valid_1's l2: 3.09186e+19
# [127]	training's rmse: 3.10049e+08	training's l2: 9.61303e+16	valid_1's rmse: 5.57434e+09	valid_1's l2: 3.10733e+19
# [128]	training's rmse: 3.06709e+08	training's l2: 9.40704e+16	valid_1's rmse: 5.58756e+09	valid_1's l2: 3.12209e+19
# [129]	training's rmse: 3.0354e+08	training's l2: 9.21364e+16	valid_1's rmse: 5.57254e+09	valid_1's l2: 3.10532e+19
# [130]	training's rmse: 3.00097e+08	training's l2: 9.00582e+16	valid_1's rmse: 5.57997e+09	valid_1's l2: 3.11361e+19
# [131]	training's rmse: 2.95517e+08	training's l2: 8.73305e+16	valid_1's rmse: 5.569e+09	valid_1's l2: 3.10138e+19
# [132]	training's rmse: 2.92361e+08	training's l2: 8.54751e+16	valid_1's rmse: 5.57521e+09	valid_1's l2: 3.1083e+19
# [133]	training's rmse: 2.89572e+08	training's l2: 8.38519e+16	valid_1's rmse: 5.56881e+09	valid_1's l2: 3.10116e+19
# [134]	training's rmse: 2.84844e+08	training's l2: 8.11363e+16	valid_1's rmse: 5.55534e+09	valid_1's l2: 3.08618e+19
# [135]	training's rmse: 2.82554e+08	training's l2: 7.98366e+16	valid_1's rmse: 5.5624e+09	valid_1's l2: 3.09403e+19
# [136]	training's rmse: 2.79545e+08	training's l2: 7.81454e+16	valid_1's rmse: 5.5684e+09	valid_1's l2: 3.10071e+19
# [137]	training's rmse: 2.74797e+08	training's l2: 7.55135e+16	valid_1's rmse: 5.5535e+09	valid_1's l2: 3.08413e+19
# [138]	training's rmse: 2.7086e+08	training's l2: 7.3365e+16	valid_1's rmse: 5.5522e+09	valid_1's l2: 3.08269e+19
# [139]	training's rmse: 2.67254e+08	training's l2: 7.14248e+16	valid_1's rmse: 5.53853e+09	valid_1's l2: 3.06753e+19
# [140]	training's rmse: 2.64835e+08	training's l2: 7.01377e+16	valid_1's rmse: 5.54526e+09	valid_1's l2: 3.07499e+19
# [141]	training's rmse: 2.61241e+08	training's l2: 6.82469e+16	valid_1's rmse: 5.53162e+09	valid_1's l2: 3.05988e+19
# [142]	training's rmse: 2.58301e+08	training's l2: 6.67194e+16	valid_1's rmse: 5.51955e+09	valid_1's l2: 3.04654e+19
# [143]	training's rmse: 2.55949e+08	training's l2: 6.55097e+16	valid_1's rmse: 5.53157e+09	valid_1's l2: 3.05983e+19
# [144]	training's rmse: 2.52977e+08	training's l2: 6.39974e+16	valid_1's rmse: 5.53856e+09	valid_1's l2: 3.06757e+19
# [145]	training's rmse: 2.50303e+08	training's l2: 6.26517e+16	valid_1's rmse: 5.54218e+09	valid_1's l2: 3.07157e+19
# [146]	training's rmse: 2.47038e+08	training's l2: 6.10276e+16	valid_1's rmse: 5.53611e+09	valid_1's l2: 3.06485e+19
# [147]	training's rmse: 2.43668e+08	training's l2: 5.93743e+16	valid_1's rmse: 5.54865e+09	valid_1's l2: 3.07875e+19
# [148]	training's rmse: 2.41662e+08	training's l2: 5.84005e+16	valid_1's rmse: 5.55446e+09	valid_1's l2: 3.08521e+19
# [149]	training's rmse: 2.38624e+08	training's l2: 5.69413e+16	valid_1's rmse: 5.56315e+09	valid_1's l2: 3.09487e+19
# [150]	training's rmse: 2.36164e+08	training's l2: 5.57737e+16	valid_1's rmse: 5.57507e+09	valid_1's l2: 3.10814e+19
# [151]	training's rmse: 2.33656e+08	training's l2: 5.45952e+16	valid_1's rmse: 5.58082e+09	valid_1's l2: 3.11455e+19
# [152]	training's rmse: 2.3122e+08	training's l2: 5.34627e+16	valid_1's rmse: 5.58676e+09	valid_1's l2: 3.12119e+19
# [153]	training's rmse: 2.28028e+08	training's l2: 5.19966e+16	valid_1's rmse: 5.57576e+09	valid_1's l2: 3.10891e+19
# [154]	training's rmse: 2.26154e+08	training's l2: 5.11454e+16	valid_1's rmse: 5.57927e+09	valid_1's l2: 3.11282e+19
# [155]	training's rmse: 2.23078e+08	training's l2: 4.97638e+16	valid_1's rmse: 5.57433e+09	valid_1's l2: 3.10732e+19
# [156]	training's rmse: 2.204e+08	training's l2: 4.8576e+16	valid_1's rmse: 5.56308e+09	valid_1's l2: 3.09478e+19
# [157]	training's rmse: 2.18488e+08	training's l2: 4.77371e+16	valid_1's rmse: 5.56833e+09	valid_1's l2: 3.10063e+19
# [158]	training's rmse: 2.15463e+08	training's l2: 4.64245e+16	valid_1's rmse: 5.57603e+09	valid_1's l2: 3.10921e+19
# [159]	training's rmse: 2.13742e+08	training's l2: 4.56857e+16	valid_1's rmse: 5.5802e+09	valid_1's l2: 3.11386e+19
# [160]	training's rmse: 2.10911e+08	training's l2: 4.44836e+16	valid_1's rmse: 5.57915e+09	valid_1's l2: 3.11269e+19
# [161]	training's rmse: 2.09356e+08	training's l2: 4.38298e+16	valid_1's rmse: 5.58407e+09	valid_1's l2: 3.11818e+19
# [162]	training's rmse: 2.06941e+08	training's l2: 4.28246e+16	valid_1's rmse: 5.59113e+09	valid_1's l2: 3.12607e+19
# [163]	training's rmse: 2.04833e+08	training's l2: 4.19565e+16	valid_1's rmse: 5.58552e+09	valid_1's l2: 3.1198e+19
# [164]	training's rmse: 2.03258e+08	training's l2: 4.1314e+16	valid_1's rmse: 5.59421e+09	valid_1's l2: 3.12952e+19
# [165]	training's rmse: 2.01e+08	training's l2: 4.0401e+16	valid_1's rmse: 5.58971e+09	valid_1's l2: 3.12449e+19
# [166]	training's rmse: 1.99403e+08	training's l2: 3.97614e+16	valid_1's rmse: 5.59458e+09	valid_1's l2: 3.12994e+19
# [167]	training's rmse: 1.97296e+08	training's l2: 3.89256e+16	valid_1's rmse: 5.59728e+09	valid_1's l2: 3.13296e+19
# [168]	training's rmse: 1.94329e+08	training's l2: 3.77638e+16	valid_1's rmse: 5.59814e+09	valid_1's l2: 3.13392e+19
# [169]	training's rmse: 1.92157e+08	training's l2: 3.69242e+16	valid_1's rmse: 5.59364e+09	valid_1's l2: 3.12888e+19
# [170]	training's rmse: 1.90746e+08	training's l2: 3.63841e+16	valid_1's rmse: 5.59939e+09	valid_1's l2: 3.13531e+19
# [171]	training's rmse: 1.8916e+08	training's l2: 3.57816e+16	valid_1's rmse: 5.60712e+09	valid_1's l2: 3.14398e+19
# [172]	training's rmse: 1.86606e+08	training's l2: 3.48217e+16	valid_1's rmse: 5.59935e+09	valid_1's l2: 3.13527e+19
# [173]	training's rmse: 1.84509e+08	training's l2: 3.40437e+16	valid_1's rmse: 5.59626e+09	valid_1's l2: 3.13181e+19
# [174]	training's rmse: 1.83033e+08	training's l2: 3.3501e+16	valid_1's rmse: 5.59178e+09	valid_1's l2: 3.12681e+19
# [175]	training's rmse: 1.81502e+08	training's l2: 3.29429e+16	valid_1's rmse: 5.59214e+09	valid_1's l2: 3.1272e+19
# [176]	training's rmse: 1.79669e+08	training's l2: 3.2281e+16	valid_1's rmse: 5.5878e+09	valid_1's l2: 3.12235e+19
# [177]	training's rmse: 1.77253e+08	training's l2: 3.14188e+16	valid_1's rmse: 5.58067e+09	valid_1's l2: 3.11439e+19
# [178]	training's rmse: 1.75937e+08	training's l2: 3.09539e+16	valid_1's rmse: 5.58729e+09	valid_1's l2: 3.12178e+19
# [179]	training's rmse: 1.7461e+08	training's l2: 3.04887e+16	valid_1's rmse: 5.59118e+09	valid_1's l2: 3.12613e+19
# [180]	training's rmse: 1.72553e+08	training's l2: 2.97747e+16	valid_1's rmse: 5.58276e+09	valid_1's l2: 3.11673e+19
# [181]	training's rmse: 1.70901e+08	training's l2: 2.92071e+16	valid_1's rmse: 5.58016e+09	valid_1's l2: 3.11381e+19
# [182]	training's rmse: 1.68945e+08	training's l2: 2.85424e+16	valid_1's rmse: 5.57367e+09	valid_1's l2: 3.10658e+19
# [183]	training's rmse: 1.67301e+08	training's l2: 2.79897e+16	valid_1's rmse: 5.57413e+09	valid_1's l2: 3.1071e+19
# [184]	training's rmse: 1.64888e+08	training's l2: 2.7188e+16	valid_1's rmse: 5.56679e+09	valid_1's l2: 3.09891e+19
# [185]	training's rmse: 1.6241e+08	training's l2: 2.63771e+16	valid_1's rmse: 5.57254e+09	valid_1's l2: 3.10532e+19
# [186]	training's rmse: 1.60499e+08	training's l2: 2.57598e+16	valid_1's rmse: 5.57638e+09	valid_1's l2: 3.1096e+19
# [187]	training's rmse: 1.59114e+08	training's l2: 2.53172e+16	valid_1's rmse: 5.57275e+09	valid_1's l2: 3.10556e+19
# [188]	training's rmse: 1.57054e+08	training's l2: 2.46661e+16	valid_1's rmse: 5.56614e+09	valid_1's l2: 3.09819e+19
# [189]	training's rmse: 1.54682e+08	training's l2: 2.39264e+16	valid_1's rmse: 5.55995e+09	valid_1's l2: 3.0913e+19
# [190]	training's rmse: 1.52058e+08	training's l2: 2.31217e+16	valid_1's rmse: 5.55705e+09	valid_1's l2: 3.08808e+19
# [191]	training's rmse: 1.5036e+08	training's l2: 2.2608e+16	valid_1's rmse: 5.55078e+09	valid_1's l2: 3.08112e+19
# [192]	training's rmse: 1.49085e+08	training's l2: 2.22262e+16	valid_1's rmse: 5.55265e+09	valid_1's l2: 3.08319e+19
# [193]	training's rmse: 1.47199e+08	training's l2: 2.16677e+16	valid_1's rmse: 5.54589e+09	valid_1's l2: 3.07569e+19
# [194]	training's rmse: 1.44866e+08	training's l2: 2.09863e+16	valid_1's rmse: 5.55381e+09	valid_1's l2: 3.08448e+19
# [195]	training's rmse: 1.42859e+08	training's l2: 2.04088e+16	valid_1's rmse: 5.55546e+09	valid_1's l2: 3.08632e+19
# [196]	training's rmse: 1.4137e+08	training's l2: 1.99856e+16	valid_1's rmse: 5.56072e+09	valid_1's l2: 3.09216e+19
# [197]	training's rmse: 1.39931e+08	training's l2: 1.95806e+16	valid_1's rmse: 5.5634e+09	valid_1's l2: 3.09514e+19
# [198]	training's rmse: 1.38797e+08	training's l2: 1.92645e+16	valid_1's rmse: 5.55989e+09	valid_1's l2: 3.09124e+19
# [199]	training's rmse: 1.37137e+08	training's l2: 1.88066e+16	valid_1's rmse: 5.55746e+09	valid_1's l2: 3.08854e+19
# [200]	training's rmse: 1.36079e+08	training's l2: 1.85175e+16	valid_1's rmse: 5.55411e+09	valid_1's l2: 3.08482e+19
# [201]	training's rmse: 1.34767e+08	training's l2: 1.81622e+16	valid_1's rmse: 5.55686e+09	valid_1's l2: 3.08787e+19
# [202]	training's rmse: 1.3276e+08	training's l2: 1.76253e+16	valid_1's rmse: 5.56343e+09	valid_1's l2: 3.09517e+19
# [203]	training's rmse: 1.31201e+08	training's l2: 1.72138e+16	valid_1's rmse: 5.56889e+09	valid_1's l2: 3.10125e+19
# [204]	training's rmse: 1.30123e+08	training's l2: 1.69319e+16	valid_1's rmse: 5.57331e+09	valid_1's l2: 3.10618e+19
# [205]	training's rmse: 1.28509e+08	training's l2: 1.65145e+16	valid_1's rmse: 5.57931e+09	valid_1's l2: 3.11287e+19
# [206]	training's rmse: 1.26557e+08	training's l2: 1.60168e+16	valid_1's rmse: 5.57725e+09	valid_1's l2: 3.11057e+19
# [207]	training's rmse: 1.25195e+08	training's l2: 1.56737e+16	valid_1's rmse: 5.57979e+09	valid_1's l2: 3.11341e+19
# [208]	training's rmse: 1.23756e+08	training's l2: 1.53155e+16	valid_1's rmse: 5.57662e+09	valid_1's l2: 3.10987e+19
# [209]	training's rmse: 1.22388e+08	training's l2: 1.49789e+16	valid_1's rmse: 5.58125e+09	valid_1's l2: 3.11504e+19
# [210]	training's rmse: 1.21334e+08	training's l2: 1.4722e+16	valid_1's rmse: 5.5784e+09	valid_1's l2: 3.11186e+19
# [211]	training's rmse: 1.20117e+08	training's l2: 1.44282e+16	valid_1's rmse: 5.5808e+09	valid_1's l2: 3.11453e+19
# [212]	training's rmse: 1.18912e+08	training's l2: 1.41401e+16	valid_1's rmse: 5.58501e+09	valid_1's l2: 3.11923e+19
# [213]	training's rmse: 1.17806e+08	training's l2: 1.38782e+16	valid_1's rmse: 5.57771e+09	valid_1's l2: 3.11108e+19
# [214]	training's rmse: 1.17055e+08	training's l2: 1.37019e+16	valid_1's rmse: 5.57675e+09	valid_1's l2: 3.11001e+19
# [215]	training's rmse: 1.15814e+08	training's l2: 1.34129e+16	valid_1's rmse: 5.57401e+09	valid_1's l2: 3.10696e+19
# [216]	training's rmse: 1.14714e+08	training's l2: 1.31593e+16	valid_1's rmse: 5.58066e+09	valid_1's l2: 3.11437e+19
# [217]	training's rmse: 1.13428e+08	training's l2: 1.28658e+16	valid_1's rmse: 5.57801e+09	valid_1's l2: 3.11142e+19
# [218]	training's rmse: 1.12316e+08	training's l2: 1.26149e+16	valid_1's rmse: 5.57821e+09	valid_1's l2: 3.11164e+19
# [219]	training's rmse: 1.11335e+08	training's l2: 1.23955e+16	valid_1's rmse: 5.57558e+09	valid_1's l2: 3.1087e+19
# [220]	training's rmse: 1.10421e+08	training's l2: 1.21928e+16	valid_1's rmse: 5.57487e+09	valid_1's l2: 3.10792e+19
# [221]	training's rmse: 1.09353e+08	training's l2: 1.19582e+16	valid_1's rmse: 5.57283e+09	valid_1's l2: 3.10564e+19
# [222]	training's rmse: 1.0827e+08	training's l2: 1.17224e+16	valid_1's rmse: 5.5702e+09	valid_1's l2: 3.10271e+19
# [223]	training's rmse: 1.07324e+08	training's l2: 1.15183e+16	valid_1's rmse: 5.57225e+09	valid_1's l2: 3.105e+19
# [224]	training's rmse: 1.06502e+08	training's l2: 1.13426e+16	valid_1's rmse: 5.57473e+09	valid_1's l2: 3.10776e+19
# [225]	training's rmse: 1.05188e+08	training's l2: 1.10646e+16	valid_1's rmse: 5.57385e+09	valid_1's l2: 3.10678e+19
# [226]	training's rmse: 1.0412e+08	training's l2: 1.0841e+16	valid_1's rmse: 5.57352e+09	valid_1's l2: 3.10642e+19
# [227]	training's rmse: 1.03382e+08	training's l2: 1.06879e+16	valid_1's rmse: 5.57116e+09	valid_1's l2: 3.10379e+19
# [228]	training's rmse: 1.02427e+08	training's l2: 1.04913e+16	valid_1's rmse: 5.57036e+09	valid_1's l2: 3.10289e+19
# [229]	training's rmse: 1.01721e+08	training's l2: 1.03472e+16	valid_1's rmse: 5.56715e+09	valid_1's l2: 3.09932e+19
# [230]	training's rmse: 1.00947e+08	training's l2: 1.01902e+16	valid_1's rmse: 5.56914e+09	valid_1's l2: 3.10153e+19
# [231]	training's rmse: 1.00167e+08	training's l2: 1.00334e+16	valid_1's rmse: 5.57136e+09	valid_1's l2: 3.104e+19
# [232]	training's rmse: 9.9337e+07	training's l2: 9.86785e+15	valid_1's rmse: 5.5688e+09	valid_1's l2: 3.10115e+19
# [233]	training's rmse: 9.82219e+07	training's l2: 9.64753e+15	valid_1's rmse: 5.56317e+09	valid_1's l2: 3.09488e+19
# [234]	training's rmse: 9.75336e+07	training's l2: 9.5128e+15	valid_1's rmse: 5.56621e+09	valid_1's l2: 3.09827e+19
# [235]	training's rmse: 9.66667e+07	training's l2: 9.34444e+15	valid_1's rmse: 5.56844e+09	valid_1's l2: 3.10075e+19
# [236]	training's rmse: 9.59077e+07	training's l2: 9.19828e+15	valid_1's rmse: 5.56605e+09	valid_1's l2: 3.09809e+19
# [237]	training's rmse: 9.50087e+07	training's l2: 9.02665e+15	valid_1's rmse: 5.56391e+09	valid_1's l2: 3.09571e+19
# [238]	training's rmse: 9.42405e+07	training's l2: 8.88128e+15	valid_1's rmse: 5.56399e+09	valid_1's l2: 3.09579e+19
# [239]	training's rmse: 9.35824e+07	training's l2: 8.75767e+15	valid_1's rmse: 5.56614e+09	valid_1's l2: 3.09819e+19
# [240]	training's rmse: 9.28062e+07	training's l2: 8.613e+15	valid_1's rmse: 5.56124e+09	valid_1's l2: 3.09274e+19
# [241]	training's rmse: 9.20086e+07	training's l2: 8.46558e+15	valid_1's rmse: 5.5572e+09	valid_1's l2: 3.08824e+19
# [242]	training's rmse: 9.12703e+07	training's l2: 8.33026e+15	valid_1's rmse: 5.55486e+09	valid_1's l2: 3.08564e+19
# [243]	training's rmse: 9.03636e+07	training's l2: 8.16557e+15	valid_1's rmse: 5.55676e+09	valid_1's l2: 3.08776e+19
# [244]	training's rmse: 8.92821e+07	training's l2: 7.97129e+15	valid_1's rmse: 5.55805e+09	valid_1's l2: 3.08919e+19
# [245]	training's rmse: 8.87003e+07	training's l2: 7.86775e+15	valid_1's rmse: 5.55556e+09	valid_1's l2: 3.08642e+19
# [246]	training's rmse: 8.79996e+07	training's l2: 7.74393e+15	valid_1's rmse: 5.55331e+09	valid_1's l2: 3.08393e+19
# [247]	training's rmse: 8.71881e+07	training's l2: 7.60177e+15	valid_1's rmse: 5.54927e+09	valid_1's l2: 3.07944e+19
# [248]	training's rmse: 8.63456e+07	training's l2: 7.45555e+15	valid_1's rmse: 5.54729e+09	valid_1's l2: 3.07724e+19
# [249]	training's rmse: 8.57566e+07	training's l2: 7.35419e+15	valid_1's rmse: 5.54523e+09	valid_1's l2: 3.07496e+19
# [250]	training's rmse: 8.51861e+07	training's l2: 7.25666e+15	valid_1's rmse: 5.5472e+09	valid_1's l2: 3.07714e+19
# [251]	training's rmse: 8.45806e+07	training's l2: 7.15388e+15	valid_1's rmse: 5.54927e+09	valid_1's l2: 3.07944e+19
# [252]	training's rmse: 8.40702e+07	training's l2: 7.06779e+15	valid_1's rmse: 5.55241e+09	valid_1's l2: 3.08292e+19
# [253]	training's rmse: 8.34967e+07	training's l2: 6.9717e+15	valid_1's rmse: 5.55024e+09	valid_1's l2: 3.08052e+19
# [254]	training's rmse: 8.28997e+07	training's l2: 6.87237e+15	valid_1's rmse: 5.55215e+09	valid_1's l2: 3.08263e+19
# [255]	training's rmse: 8.22539e+07	training's l2: 6.7657e+15	valid_1's rmse: 5.55354e+09	valid_1's l2: 3.08419e+19
# [256]	training's rmse: 8.15787e+07	training's l2: 6.65509e+15	valid_1's rmse: 5.5516e+09	valid_1's l2: 3.08203e+19
# [257]	training's rmse: 8.04042e+07	training's l2: 6.46484e+15	valid_1's rmse: 5.55033e+09	valid_1's l2: 3.08062e+19
# [258]	training's rmse: 7.98502e+07	training's l2: 6.37606e+15	valid_1's rmse: 5.54824e+09	valid_1's l2: 3.0783e+19
# [259]	training's rmse: 7.89012e+07	training's l2: 6.22539e+15	valid_1's rmse: 5.55145e+09	valid_1's l2: 3.08186e+19
# [260]	training's rmse: 7.81963e+07	training's l2: 6.11467e+15	valid_1's rmse: 5.54816e+09	valid_1's l2: 3.07821e+19
# [261]	training's rmse: 7.73614e+07	training's l2: 5.98478e+15	valid_1's rmse: 5.54882e+09	valid_1's l2: 3.07894e+19
# [262]	training's rmse: 7.67858e+07	training's l2: 5.89606e+15	valid_1's rmse: 5.54676e+09	valid_1's l2: 3.07666e+19
# [263]	training's rmse: 7.58333e+07	training's l2: 5.75069e+15	valid_1's rmse: 5.54805e+09	valid_1's l2: 3.07809e+19
# [264]	training's rmse: 7.52916e+07	training's l2: 5.66882e+15	valid_1's rmse: 5.55023e+09	valid_1's l2: 3.0805e+19
# [265]	training's rmse: 7.47856e+07	training's l2: 5.59288e+15	valid_1's rmse: 5.54809e+09	valid_1's l2: 3.07814e+19
# [266]	training's rmse: 7.4184e+07	training's l2: 5.50327e+15	valid_1's rmse: 5.54479e+09	valid_1's l2: 3.07447e+19
# [267]	training's rmse: 7.3553e+07	training's l2: 5.41004e+15	valid_1's rmse: 5.54289e+09	valid_1's l2: 3.07237e+19
# [268]	training's rmse: 7.3122e+07	training's l2: 5.34682e+15	valid_1's rmse: 5.54099e+09	valid_1's l2: 3.07026e+19
# [269]	training's rmse: 7.26208e+07	training's l2: 5.27378e+15	valid_1's rmse: 5.54306e+09	valid_1's l2: 3.07255e+19
# [270]	training's rmse: 7.21179e+07	training's l2: 5.201e+15	valid_1's rmse: 5.54111e+09	valid_1's l2: 3.07039e+19
# [271]	training's rmse: 7.12765e+07	training's l2: 5.08033e+15	valid_1's rmse: 5.54401e+09	valid_1's l2: 3.0736e+19
# [272]	training's rmse: 7.06216e+07	training's l2: 4.98741e+15	valid_1's rmse: 5.54103e+09	valid_1's l2: 3.0703e+19
# [273]	training's rmse: 6.96331e+07	training's l2: 4.84876e+15	valid_1's rmse: 5.53893e+09	valid_1's l2: 3.06797e+19
# [274]	training's rmse: 6.9066e+07	training's l2: 4.77011e+15	valid_1's rmse: 5.54166e+09	valid_1's l2: 3.071e+19
# [275]	training's rmse: 6.82302e+07	training's l2: 4.65536e+15	valid_1's rmse: 5.53967e+09	valid_1's l2: 3.0688e+19
# [276]	training's rmse: 6.76988e+07	training's l2: 4.58313e+15	valid_1's rmse: 5.54165e+09	valid_1's l2: 3.07099e+19
# [277]	training's rmse: 6.68961e+07	training's l2: 4.47509e+15	valid_1's rmse: 5.53982e+09	valid_1's l2: 3.06896e+19
# [278]	training's rmse: 6.62958e+07	training's l2: 4.39514e+15	valid_1's rmse: 5.53793e+09	valid_1's l2: 3.06687e+19
# [279]	training's rmse: 6.58651e+07	training's l2: 4.33821e+15	valid_1's rmse: 5.53965e+09	valid_1's l2: 3.06877e+19
# [280]	training's rmse: 6.53651e+07	training's l2: 4.27259e+15	valid_1's rmse: 5.53775e+09	valid_1's l2: 3.06667e+19
# [281]	training's rmse: 6.48657e+07	training's l2: 4.20756e+15	valid_1's rmse: 5.53443e+09	valid_1's l2: 3.063e+19
# [282]	training's rmse: 6.42838e+07	training's l2: 4.13241e+15	valid_1's rmse: 5.53697e+09	valid_1's l2: 3.06581e+19
# [283]	training's rmse: 6.34524e+07	training's l2: 4.02621e+15	valid_1's rmse: 5.537e+09	valid_1's l2: 3.06584e+19
# [284]	training's rmse: 6.29205e+07	training's l2: 3.95899e+15	valid_1's rmse: 5.5393e+09	valid_1's l2: 3.06838e+19
# [285]	training's rmse: 6.24202e+07	training's l2: 3.89629e+15	valid_1's rmse: 5.5376e+09	valid_1's l2: 3.0665e+19
# [286]	training's rmse: 6.19399e+07	training's l2: 3.83656e+15	valid_1's rmse: 5.53594e+09	valid_1's l2: 3.06467e+19
# [287]	training's rmse: 6.12862e+07	training's l2: 3.75599e+15	valid_1's rmse: 5.53365e+09	valid_1's l2: 3.06213e+19
# [288]	training's rmse: 6.07949e+07	training's l2: 3.69602e+15	valid_1's rmse: 5.53216e+09	valid_1's l2: 3.06048e+19
# [289]	training's rmse: 6.02944e+07	training's l2: 3.63542e+15	valid_1's rmse: 5.53446e+09	valid_1's l2: 3.06302e+19
# [290]	training's rmse: 5.98573e+07	training's l2: 3.5829e+15	valid_1's rmse: 5.53415e+09	valid_1's l2: 3.06268e+19
# [291]	training's rmse: 5.92533e+07	training's l2: 3.51095e+15	valid_1's rmse: 5.5352e+09	valid_1's l2: 3.06384e+19
# [292]	training's rmse: 5.89186e+07	training's l2: 3.4714e+15	valid_1's rmse: 5.53364e+09	valid_1's l2: 3.06212e+19
# [293]	training's rmse: 5.84e+07	training's l2: 3.41056e+15	valid_1's rmse: 5.53582e+09	valid_1's l2: 3.06453e+19
# [294]	training's rmse: 5.80532e+07	training's l2: 3.37017e+15	valid_1's rmse: 5.53424e+09	valid_1's l2: 3.06278e+19
# [295]	training's rmse: 5.73724e+07	training's l2: 3.29159e+15	valid_1's rmse: 5.53145e+09	valid_1's l2: 3.05969e+19
# [296]	training's rmse: 5.69709e+07	training's l2: 3.24568e+15	valid_1's rmse: 5.53357e+09	valid_1's l2: 3.06204e+19
# [297]	training's rmse: 5.66847e+07	training's l2: 3.21316e+15	valid_1's rmse: 5.53205e+09	valid_1's l2: 3.06036e+19
# [298]	training's rmse: 5.61074e+07	training's l2: 3.14804e+15	valid_1's rmse: 5.53196e+09	valid_1's l2: 3.06026e+19
# [299]	training's rmse: 5.56459e+07	training's l2: 3.09647e+15	valid_1's rmse: 5.53311e+09	valid_1's l2: 3.06153e+19
# [300]	training's rmse: 5.51831e+07	training's l2: 3.04517e+15	valid_1's rmse: 5.53155e+09	valid_1's l2: 3.0598e+19
# [301]	training's rmse: 5.48464e+07	training's l2: 3.00813e+15	valid_1's rmse: 5.52894e+09	valid_1's l2: 3.05692e+19
# [302]	training's rmse: 5.451e+07	training's l2: 2.97134e+15	valid_1's rmse: 5.53024e+09	valid_1's l2: 3.05836e+19
# [303]	training's rmse: 5.40436e+07	training's l2: 2.92071e+15	valid_1's rmse: 5.53241e+09	valid_1's l2: 3.06076e+19
# [304]	training's rmse: 5.37494e+07	training's l2: 2.889e+15	valid_1's rmse: 5.53364e+09	valid_1's l2: 3.06212e+19
# [305]	training's rmse: 5.3486e+07	training's l2: 2.86075e+15	valid_1's rmse: 5.53225e+09	valid_1's l2: 3.06058e+19
# [306]	training's rmse: 5.29942e+07	training's l2: 2.80838e+15	valid_1's rmse: 5.53335e+09	valid_1's l2: 3.0618e+19
# [307]	training's rmse: 5.23962e+07	training's l2: 2.74536e+15	valid_1's rmse: 5.53415e+09	valid_1's l2: 3.06268e+19
# [308]	training's rmse: 5.20067e+07	training's l2: 2.7047e+15	valid_1's rmse: 5.53257e+09	valid_1's l2: 3.06093e+19
# [309]	training's rmse: 5.17385e+07	training's l2: 2.67687e+15	valid_1's rmse: 5.53114e+09	valid_1's l2: 3.05935e+19
# [310]	training's rmse: 5.14485e+07	training's l2: 2.64695e+15	valid_1's rmse: 5.53311e+09	valid_1's l2: 3.06153e+19
# [311]	training's rmse: 5.11023e+07	training's l2: 2.61145e+15	valid_1's rmse: 5.53167e+09	valid_1's l2: 3.05994e+19
# [312]	training's rmse: 5.07487e+07	training's l2: 2.57543e+15	valid_1's rmse: 5.53314e+09	valid_1's l2: 3.06156e+19
# [313]	training's rmse: 5.04301e+07	training's l2: 2.5432e+15	valid_1's rmse: 5.53505e+09	valid_1's l2: 3.06368e+19
# [314]	training's rmse: 5.01462e+07	training's l2: 2.51464e+15	valid_1's rmse: 5.5336e+09	valid_1's l2: 3.06208e+19
# [315]	training's rmse: 4.98239e+07	training's l2: 2.48243e+15	valid_1's rmse: 5.53343e+09	valid_1's l2: 3.06189e+19
# [316]	training's rmse: 4.94785e+07	training's l2: 2.44813e+15	valid_1's rmse: 5.53224e+09	valid_1's l2: 3.06057e+19
# [317]	training's rmse: 4.91388e+07	training's l2: 2.41462e+15	valid_1's rmse: 5.53411e+09	valid_1's l2: 3.06264e+19
# [318]	training's rmse: 4.87925e+07	training's l2: 2.38071e+15	valid_1's rmse: 5.53272e+09	valid_1's l2: 3.0611e+19
# [319]	training's rmse: 4.84301e+07	training's l2: 2.34547e+15	valid_1's rmse: 5.53262e+09	valid_1's l2: 3.06098e+19
# [320]	training's rmse: 4.81737e+07	training's l2: 2.32071e+15	valid_1's rmse: 5.53131e+09	valid_1's l2: 3.05954e+19
# [321]	training's rmse: 4.79103e+07	training's l2: 2.2954e+15	valid_1's rmse: 5.53318e+09	valid_1's l2: 3.0616e+19
# [322]	training's rmse: 4.76751e+07	training's l2: 2.27291e+15	valid_1's rmse: 5.53185e+09	valid_1's l2: 3.06014e+19
# [323]	training's rmse: 4.74227e+07	training's l2: 2.24891e+15	valid_1's rmse: 5.53172e+09	valid_1's l2: 3.06e+19
# [324]	training's rmse: 4.7026e+07	training's l2: 2.21145e+15	valid_1's rmse: 5.53349e+09	valid_1's l2: 3.06196e+19
# [325]	training's rmse: 4.65935e+07	training's l2: 2.17096e+15	valid_1's rmse: 5.53239e+09	valid_1's l2: 3.06073e+19
# [326]	training's rmse: 4.63782e+07	training's l2: 2.15094e+15	valid_1's rmse: 5.53111e+09	valid_1's l2: 3.05932e+19
# [327]	training's rmse: 4.60127e+07	training's l2: 2.11717e+15	valid_1's rmse: 5.53101e+09	valid_1's l2: 3.0592e+19
# [328]	training's rmse: 4.56458e+07	training's l2: 2.08353e+15	valid_1's rmse: 5.53265e+09	valid_1's l2: 3.06102e+19
# [329]	training's rmse: 4.53409e+07	training's l2: 2.0558e+15	valid_1's rmse: 5.53249e+09	valid_1's l2: 3.06085e+19
# [330]	training's rmse: 4.4703e+07	training's l2: 1.99835e+15	valid_1's rmse: 5.53077e+09	valid_1's l2: 3.05894e+19
# [331]	training's rmse: 4.44568e+07	training's l2: 1.97641e+15	valid_1's rmse: 5.53208e+09	valid_1's l2: 3.06039e+19
# [332]	training's rmse: 4.4174e+07	training's l2: 1.95134e+15	valid_1's rmse: 5.53082e+09	valid_1's l2: 3.05899e+19
# [333]	training's rmse: 4.38615e+07	training's l2: 1.92383e+15	valid_1's rmse: 5.52867e+09	valid_1's l2: 3.05662e+19
# [334]	training's rmse: 4.36483e+07	training's l2: 1.90518e+15	valid_1's rmse: 5.5298e+09	valid_1's l2: 3.05787e+19
# [335]	training's rmse: 4.33624e+07	training's l2: 1.88029e+15	valid_1's rmse: 5.53156e+09	valid_1's l2: 3.05981e+19
# [336]	training's rmse: 4.31153e+07	training's l2: 1.85893e+15	valid_1's rmse: 5.53034e+09	valid_1's l2: 3.05847e+19
# [337]	training's rmse: 4.28506e+07	training's l2: 1.83618e+15	valid_1's rmse: 5.53017e+09	valid_1's l2: 3.05828e+19
# [338]	training's rmse: 4.25523e+07	training's l2: 1.81069e+15	valid_1's rmse: 5.52904e+09	valid_1's l2: 3.05703e+19
# [339]	training's rmse: 4.23229e+07	training's l2: 1.79123e+15	valid_1's rmse: 5.5308e+09	valid_1's l2: 3.05898e+19
# [340]	training's rmse: 4.21097e+07	training's l2: 1.77323e+15	valid_1's rmse: 5.52965e+09	valid_1's l2: 3.0577e+19
# [341]	training's rmse: 4.15752e+07	training's l2: 1.72849e+15	valid_1's rmse: 5.52807e+09	valid_1's l2: 3.05595e+19
# [342]	training's rmse: 4.13606e+07	training's l2: 1.7107e+15	valid_1's rmse: 5.52907e+09	valid_1's l2: 3.05706e+19
# [343]	training's rmse: 4.11626e+07	training's l2: 1.69436e+15	valid_1's rmse: 5.52797e+09	valid_1's l2: 3.05585e+19
# [344]	training's rmse: 4.09552e+07	training's l2: 1.67733e+15	valid_1's rmse: 5.52966e+09	valid_1's l2: 3.05772e+19
# [345]	training's rmse: 4.06684e+07	training's l2: 1.65392e+15	valid_1's rmse: 5.53097e+09	valid_1's l2: 3.05917e+19
# [346]	training's rmse: 4.05047e+07	training's l2: 1.64063e+15	valid_1's rmse: 5.52982e+09	valid_1's l2: 3.05789e+19
# [347]	training's rmse: 4.02635e+07	training's l2: 1.62115e+15	valid_1's rmse: 5.52971e+09	valid_1's l2: 3.05777e+19
# [348]	training's rmse: 3.98618e+07	training's l2: 1.58896e+15	valid_1's rmse: 5.52873e+09	valid_1's l2: 3.05669e+19
# [349]	training's rmse: 3.96688e+07	training's l2: 1.57361e+15	valid_1's rmse: 5.52865e+09	valid_1's l2: 3.0566e+19
# [350]	training's rmse: 3.93236e+07	training's l2: 1.54635e+15	valid_1's rmse: 5.52768e+09	valid_1's l2: 3.05552e+19
# [351]	training's rmse: 3.91165e+07	training's l2: 1.5301e+15	valid_1's rmse: 5.52923e+09	valid_1's l2: 3.05724e+19
# [352]	training's rmse: 3.89392e+07	training's l2: 1.51626e+15	valid_1's rmse: 5.5281e+09	valid_1's l2: 3.05599e+19
# [353]	training's rmse: 3.87654e+07	training's l2: 1.50276e+15	valid_1's rmse: 5.5279e+09	valid_1's l2: 3.05577e+19
# [354]	training's rmse: 3.84794e+07	training's l2: 1.48067e+15	valid_1's rmse: 5.52743e+09	valid_1's l2: 3.05524e+19
# [355]	training's rmse: 3.8188e+07	training's l2: 1.45832e+15	valid_1's rmse: 5.52828e+09	valid_1's l2: 3.05619e+19
# [356]	training's rmse: 3.7969e+07	training's l2: 1.44165e+15	valid_1's rmse: 5.52954e+09	valid_1's l2: 3.05758e+19
# [357]	training's rmse: 3.77695e+07	training's l2: 1.42654e+15	valid_1's rmse: 5.52852e+09	valid_1's l2: 3.05646e+19
# [358]	training's rmse: 3.75728e+07	training's l2: 1.41171e+15	valid_1's rmse: 5.52948e+09	valid_1's l2: 3.05752e+19
# [359]	training's rmse: 3.72116e+07	training's l2: 1.3847e+15	valid_1's rmse: 5.52695e+09	valid_1's l2: 3.05472e+19
# [360]	training's rmse: 3.69898e+07	training's l2: 1.36825e+15	valid_1's rmse: 5.52824e+09	valid_1's l2: 3.05615e+19
# [361]	training's rmse: 3.68187e+07	training's l2: 1.35562e+15	valid_1's rmse: 5.52922e+09	valid_1's l2: 3.05723e+19
# [362]	training's rmse: 3.65984e+07	training's l2: 1.33944e+15	valid_1's rmse: 5.53071e+09	valid_1's l2: 3.05887e+19
# [363]	training's rmse: 3.64606e+07	training's l2: 1.32937e+15	valid_1's rmse: 5.52963e+09	valid_1's l2: 3.05768e+19
# [364]	training's rmse: 3.63e+07	training's l2: 1.31769e+15	valid_1's rmse: 5.52866e+09	valid_1's l2: 3.05661e+19
# [365]	training's rmse: 3.61511e+07	training's l2: 1.3069e+15	valid_1's rmse: 5.52958e+09	valid_1's l2: 3.05762e+19
# [366]	training's rmse: 3.59822e+07	training's l2: 1.29472e+15	valid_1's rmse: 5.531e+09	valid_1's l2: 3.0592e+19
# [367]	training's rmse: 3.58331e+07	training's l2: 1.28401e+15	valid_1's rmse: 5.52992e+09	valid_1's l2: 3.05801e+19
# [368]	training's rmse: 3.56493e+07	training's l2: 1.27087e+15	valid_1's rmse: 5.52977e+09	valid_1's l2: 3.05783e+19
# [369]	training's rmse: 3.5495e+07	training's l2: 1.25989e+15	valid_1's rmse: 5.52877e+09	valid_1's l2: 3.05673e+19
# [370]	training's rmse: 3.52564e+07	training's l2: 1.24301e+15	valid_1's rmse: 5.52954e+09	valid_1's l2: 3.05758e+19
# [371]	training's rmse: 3.49715e+07	training's l2: 1.223e+15	valid_1's rmse: 5.53032e+09	valid_1's l2: 3.05844e+19
# [372]	training's rmse: 3.44521e+07	training's l2: 1.18695e+15	valid_1's rmse: 5.52809e+09	valid_1's l2: 3.05598e+19
# [373]	training's rmse: 3.40543e+07	training's l2: 1.1597e+15	valid_1's rmse: 5.52977e+09	valid_1's l2: 3.05784e+19
# [374]	training's rmse: 3.39007e+07	training's l2: 1.14926e+15	valid_1's rmse: 5.52873e+09	valid_1's l2: 3.05669e+19
# [375]	training's rmse: 3.36178e+07	training's l2: 1.13016e+15	valid_1's rmse: 5.52779e+09	valid_1's l2: 3.05565e+19
# [376]	training's rmse: 3.34251e+07	training's l2: 1.11724e+15	valid_1's rmse: 5.5292e+09	valid_1's l2: 3.05721e+19
# [377]	training's rmse: 3.32825e+07	training's l2: 1.10773e+15	valid_1's rmse: 5.52824e+09	valid_1's l2: 3.05615e+19
# [378]	training's rmse: 3.30781e+07	training's l2: 1.09416e+15	valid_1's rmse: 5.52939e+09	valid_1's l2: 3.05741e+19
# [379]	training's rmse: 3.28847e+07	training's l2: 1.08141e+15	valid_1's rmse: 5.52919e+09	valid_1's l2: 3.05719e+19
# [380]	training's rmse: 3.26885e+07	training's l2: 1.06854e+15	valid_1's rmse: 5.53048e+09	valid_1's l2: 3.05862e+19
# [381]	training's rmse: 3.2538e+07	training's l2: 1.05872e+15	valid_1's rmse: 5.52946e+09	valid_1's l2: 3.0575e+19
# [382]	training's rmse: 3.23771e+07	training's l2: 1.04827e+15	valid_1's rmse: 5.52855e+09	valid_1's l2: 3.05648e+19
# [383]	training's rmse: 3.22224e+07	training's l2: 1.03828e+15	valid_1's rmse: 5.52988e+09	valid_1's l2: 3.05796e+19
# [384]	training's rmse: 3.20871e+07	training's l2: 1.02958e+15	valid_1's rmse: 5.52895e+09	valid_1's l2: 3.05693e+19
# [385]	training's rmse: 3.19118e+07	training's l2: 1.01837e+15	valid_1's rmse: 5.52878e+09	valid_1's l2: 3.05675e+19
# [386]	training's rmse: 3.16898e+07	training's l2: 1.00425e+15	valid_1's rmse: 5.52951e+09	valid_1's l2: 3.05754e+19
# [387]	training's rmse: 3.15708e+07	training's l2: 9.96717e+14	valid_1's rmse: 5.52863e+09	valid_1's l2: 3.05658e+19
# [388]	training's rmse: 3.14466e+07	training's l2: 9.88891e+14	valid_1's rmse: 5.52944e+09	valid_1's l2: 3.05747e+19
# [389]	training's rmse: 3.12552e+07	training's l2: 9.76888e+14	valid_1's rmse: 5.53099e+09	valid_1's l2: 3.05919e+19
# [390]	training's rmse: 3.08847e+07	training's l2: 9.53863e+14	valid_1's rmse: 5.52961e+09	valid_1's l2: 3.05765e+19
# [391]	training's rmse: 3.06395e+07	training's l2: 9.38782e+14	valid_1's rmse: 5.5303e+09	valid_1's l2: 3.05843e+19
# [392]	training's rmse: 3.052e+07	training's l2: 9.31468e+14	valid_1's rmse: 5.52972e+09	valid_1's l2: 3.05778e+19
# [393]	training's rmse: 3.03801e+07	training's l2: 9.2295e+14	valid_1's rmse: 5.52889e+09	valid_1's l2: 3.05686e+19
# [394]	training's rmse: 3.01887e+07	training's l2: 9.11359e+14	valid_1's rmse: 5.53022e+09	valid_1's l2: 3.05833e+19
# [395]	training's rmse: 2.99994e+07	training's l2: 8.99966e+14	valid_1's rmse: 5.53129e+09	valid_1's l2: 3.05952e+19
# [396]	training's rmse: 2.97493e+07	training's l2: 8.85021e+14	valid_1's rmse: 5.53052e+09	valid_1's l2: 3.05866e+19
# [397]	training's rmse: 2.96483e+07	training's l2: 8.79022e+14	valid_1's rmse: 5.5296e+09	valid_1's l2: 3.05764e+19
# [398]	training's rmse: 2.94016e+07	training's l2: 8.64453e+14	valid_1's rmse: 5.52893e+09	valid_1's l2: 3.05691e+19
# [399]	training's rmse: 2.90272e+07	training's l2: 8.42579e+14	valid_1's rmse: 5.5277e+09	valid_1's l2: 3.05555e+19
# [400]	training's rmse: 2.88643e+07	training's l2: 8.33147e+14	valid_1's rmse: 5.52688e+09	valid_1's l2: 3.05464e+19
# [401]	training's rmse: 2.86927e+07	training's l2: 8.23269e+14	valid_1's rmse: 5.52755e+09	valid_1's l2: 3.05538e+19
# [402]	training's rmse: 2.85778e+07	training's l2: 8.16688e+14	valid_1's rmse: 5.52724e+09	valid_1's l2: 3.05504e+19
# [403]	training's rmse: 2.8428e+07	training's l2: 8.08151e+14	valid_1's rmse: 5.52788e+09	valid_1's l2: 3.05575e+19
# [404]	training's rmse: 2.81756e+07	training's l2: 7.93862e+14	valid_1's rmse: 5.52737e+09	valid_1's l2: 3.05518e+19
# [405]	training's rmse: 2.80897e+07	training's l2: 7.8903e+14	valid_1's rmse: 5.52654e+09	valid_1's l2: 3.05426e+19
# [406]	training's rmse: 2.79136e+07	training's l2: 7.79169e+14	valid_1's rmse: 5.52653e+09	valid_1's l2: 3.05426e+19
# [407]	training's rmse: 2.77896e+07	training's l2: 7.7226e+14	valid_1's rmse: 5.52726e+09	valid_1's l2: 3.05506e+19
# [408]	training's rmse: 2.75895e+07	training's l2: 7.61183e+14	valid_1's rmse: 5.52665e+09	valid_1's l2: 3.05439e+19
# [409]	training's rmse: 2.73468e+07	training's l2: 7.47849e+14	valid_1's rmse: 5.52555e+09	valid_1's l2: 3.05317e+19
# [410]	training's rmse: 2.72255e+07	training's l2: 7.41227e+14	valid_1's rmse: 5.52534e+09	valid_1's l2: 3.05294e+19
# [411]	training's rmse: 2.69239e+07	training's l2: 7.24897e+14	valid_1's rmse: 5.52341e+09	valid_1's l2: 3.0508e+19
# [412]	training's rmse: 2.67243e+07	training's l2: 7.14187e+14	valid_1's rmse: 5.52274e+09	valid_1's l2: 3.05006e+19
# [413]	training's rmse: 2.64216e+07	training's l2: 6.98102e+14	valid_1's rmse: 5.52158e+09	valid_1's l2: 3.04879e+19
# [414]	training's rmse: 2.62026e+07	training's l2: 6.86578e+14	valid_1's rmse: 5.52218e+09	valid_1's l2: 3.04944e+19
# [415]	training's rmse: 2.59815e+07	training's l2: 6.75041e+14	valid_1's rmse: 5.5215e+09	valid_1's l2: 3.0487e+19
# [416]	training's rmse: 2.58612e+07	training's l2: 6.68804e+14	valid_1's rmse: 5.52074e+09	valid_1's l2: 3.04785e+19
# [417]	training's rmse: 2.57255e+07	training's l2: 6.61803e+14	valid_1's rmse: 5.52046e+09	valid_1's l2: 3.04754e+19
# [418]	training's rmse: 2.55787e+07	training's l2: 6.54269e+14	valid_1's rmse: 5.52117e+09	valid_1's l2: 3.04833e+19
# ...
# [4861]	training's rmse: 0.176026	training's l2: 0.0309851	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4862]	training's rmse: 0.17549	training's l2: 0.0307967	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4863]	training's rmse: 0.175115	training's l2: 0.0306653	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4864]	training's rmse: 0.17466	training's l2: 0.0305059	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4865]	training's rmse: 0.174259	training's l2: 0.0303663	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4866]	training's rmse: 0.173298	training's l2: 0.0300322	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4867]	training's rmse: 0.172846	training's l2: 0.0298759	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4868]	training's rmse: 0.172353	training's l2: 0.0297055	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4869]	training's rmse: 0.171998	training's l2: 0.0295832	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4870]	training's rmse: 0.171634	training's l2: 0.0294583	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4871]	training's rmse: 0.171128	training's l2: 0.0292849	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4872]	training's rmse: 0.170719	training's l2: 0.0291451	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4873]	training's rmse: 0.170329	training's l2: 0.0290119	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4874]	training's rmse: 0.16861	training's l2: 0.0284292	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4875]	training's rmse: 0.168096	training's l2: 0.0282562	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4876]	training's rmse: 0.167041	training's l2: 0.0279028	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4877]	training's rmse: 0.166691	training's l2: 0.0277859	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4878]	training's rmse: 0.165708	training's l2: 0.027459	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4879]	training's rmse: 0.165361	training's l2: 0.0273444	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4880]	training's rmse: 0.164948	training's l2: 0.0272078	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4881]	training's rmse: 0.164476	training's l2: 0.0270523	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4882]	training's rmse: 0.164127	training's l2: 0.0269377	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4883]	training's rmse: 0.162507	training's l2: 0.0264087	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4884]	training's rmse: 0.16153	training's l2: 0.0260919	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4885]	training's rmse: 0.161052	training's l2: 0.0259378	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4886]	training's rmse: 0.160706	training's l2: 0.0258264	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4887]	training's rmse: 0.160343	training's l2: 0.0257099	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4888]	training's rmse: 0.16004	training's l2: 0.0256129	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4889]	training's rmse: 0.159542	training's l2: 0.0254538	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4890]	training's rmse: 0.15908	training's l2: 0.0253066	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4891]	training's rmse: 0.158771	training's l2: 0.0252082	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4892]	training's rmse: 0.158455	training's l2: 0.0251079	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4893]	training's rmse: 0.157956	training's l2: 0.0249501	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4894]	training's rmse: 0.156953	training's l2: 0.0246343	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4895]	training's rmse: 0.156502	training's l2: 0.0244929	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4896]	training's rmse: 0.156215	training's l2: 0.0244032	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4897]	training's rmse: 0.155728	training's l2: 0.0242512	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4898]	training's rmse: 0.154138	training's l2: 0.0237585	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4899]	training's rmse: 0.153671	training's l2: 0.0236148	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4900]	training's rmse: 0.153258	training's l2: 0.0234879	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4901]	training's rmse: 0.152937	training's l2: 0.0233899	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4902]	training's rmse: 0.152596	training's l2: 0.0232855	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4903]	training's rmse: 0.152292	training's l2: 0.0231927	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4904]	training's rmse: 0.150747	training's l2: 0.0227247	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4905]	training's rmse: 0.150432	training's l2: 0.0226297	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4906]	training's rmse: 0.149898	training's l2: 0.0224693	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4907]	training's rmse: 0.149505	training's l2: 0.0223517	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4908]	training's rmse: 0.149062	training's l2: 0.0222194	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4909]	training's rmse: 0.148642	training's l2: 0.0220945	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4910]	training's rmse: 0.148298	training's l2: 0.0219922	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4911]	training's rmse: 0.147824	training's l2: 0.0218521	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4912]	training's rmse: 0.147417	training's l2: 0.0217317	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4913]	training's rmse: 0.147068	training's l2: 0.021629	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4914]	training's rmse: 0.146731	training's l2: 0.0215299	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4915]	training's rmse: 0.145839	training's l2: 0.021269	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4916]	training's rmse: 0.145455	training's l2: 0.0211572	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4917]	training's rmse: 0.145038	training's l2: 0.0210359	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4918]	training's rmse: 0.144763	training's l2: 0.0209563	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4919]	training's rmse: 0.144431	training's l2: 0.0208602	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4920]	training's rmse: 0.143184	training's l2: 0.0205017	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4921]	training's rmse: 0.141892	training's l2: 0.0201334	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4922]	training's rmse: 0.141454	training's l2: 0.0200091	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4923]	training's rmse: 0.140915	training's l2: 0.0198571	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4924]	training's rmse: 0.140657	training's l2: 0.0197845	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4925]	training's rmse: 0.138933	training's l2: 0.0193025	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4926]	training's rmse: 0.137953	training's l2: 0.0190311	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4927]	training's rmse: 0.137232	training's l2: 0.0188327	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4928]	training's rmse: 0.136691	training's l2: 0.0186845	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4929]	training's rmse: 0.136423	training's l2: 0.0186112	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4930]	training's rmse: 0.136021	training's l2: 0.0185016	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4931]	training's rmse: 0.135747	training's l2: 0.0184274	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4932]	training's rmse: 0.134926	training's l2: 0.0182049	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4933]	training's rmse: 0.134485	training's l2: 0.0180862	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4934]	training's rmse: 0.134088	training's l2: 0.0179796	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4935]	training's rmse: 0.133028	training's l2: 0.0176964	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4936]	training's rmse: 0.132642	training's l2: 0.0175939	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4937]	training's rmse: 0.132374	training's l2: 0.0175228	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4938]	training's rmse: 0.131693	training's l2: 0.0173432	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4939]	training's rmse: 0.131191	training's l2: 0.0172111	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4940]	training's rmse: 0.130696	training's l2: 0.0170814	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4941]	training's rmse: 0.130387	training's l2: 0.0170009	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4942]	training's rmse: 0.130084	training's l2: 0.0169218	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4943]	training's rmse: 0.128552	training's l2: 0.0165256	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4944]	training's rmse: 0.127215	training's l2: 0.0161837	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4945]	training's rmse: 0.126956	training's l2: 0.0161178	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4946]	training's rmse: 0.126139	training's l2: 0.0159111	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4947]	training's rmse: 0.12579	training's l2: 0.0158232	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4948]	training's rmse: 0.125427	training's l2: 0.015732	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4949]	training's rmse: 0.125171	training's l2: 0.0156677	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4950]	training's rmse: 0.124055	training's l2: 0.0153897	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4951]	training's rmse: 0.12368	training's l2: 0.0152968	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4952]	training's rmse: 0.123452	training's l2: 0.0152404	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4953]	training's rmse: 0.123104	training's l2: 0.0151545	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4954]	training's rmse: 0.12285	training's l2: 0.0150922	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4955]	training's rmse: 0.122546	training's l2: 0.0150175	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4956]	training's rmse: 0.121306	training's l2: 0.0147152	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4957]	training's rmse: 0.120942	training's l2: 0.0146271	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4958]	training's rmse: 0.120721	training's l2: 0.0145735	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4959]	training's rmse: 0.119947	training's l2: 0.0143873	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4960]	training's rmse: 0.119598	training's l2: 0.0143036	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4961]	training's rmse: 0.119367	training's l2: 0.0142485	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4962]	training's rmse: 0.11902	training's l2: 0.0141657	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4963]	training's rmse: 0.118382	training's l2: 0.0140143	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4964]	training's rmse: 0.118162	training's l2: 0.0139621	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4965]	training's rmse: 0.117418	training's l2: 0.013787	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4966]	training's rmse: 0.117071	training's l2: 0.0137056	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4967]	training's rmse: 0.116801	training's l2: 0.0136424	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4968]	training's rmse: 0.116122	training's l2: 0.0134842	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4969]	training's rmse: 0.115377	training's l2: 0.0133118	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4970]	training's rmse: 0.115104	training's l2: 0.013249	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4971]	training's rmse: 0.114085	training's l2: 0.0130155	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4972]	training's rmse: 0.113756	training's l2: 0.0129405	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4973]	training's rmse: 0.113494	training's l2: 0.0128809	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4974]	training's rmse: 0.11322	training's l2: 0.0128188	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4975]	training's rmse: 0.112841	training's l2: 0.0127332	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4976]	training's rmse: 0.112614	training's l2: 0.0126818	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4977]	training's rmse: 0.112315	training's l2: 0.0126147	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4978]	training's rmse: 0.111979	training's l2: 0.0125394	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4979]	training's rmse: 0.111755	training's l2: 0.0124891	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4980]	training's rmse: 0.111409	training's l2: 0.012412	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4981]	training's rmse: 0.110783	training's l2: 0.0122729	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4982]	training's rmse: 0.110473	training's l2: 0.0122043	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4983]	training's rmse: 0.110121	training's l2: 0.0121266	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4984]	training's rmse: 0.109847	training's l2: 0.0120665	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4985]	training's rmse: 0.109433	training's l2: 0.0119755	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4986]	training's rmse: 0.109221	training's l2: 0.0119293	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4987]	training's rmse: 0.108918	training's l2: 0.0118632	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4988]	training's rmse: 0.108691	training's l2: 0.0118137	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4989]	training's rmse: 0.108455	training's l2: 0.0117624	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4990]	training's rmse: 0.107379	training's l2: 0.0115302	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4991]	training's rmse: 0.107112	training's l2: 0.011473	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4992]	training's rmse: 0.106865	training's l2: 0.01142	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4993]	training's rmse: 0.106088	training's l2: 0.0112547	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4994]	training's rmse: 0.105097	training's l2: 0.0110454	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4995]	training's rmse: 0.104777	training's l2: 0.0109782	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4996]	training's rmse: 0.104196	training's l2: 0.0108568	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4997]	training's rmse: 0.103801	training's l2: 0.0107745	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4998]	training's rmse: 0.103594	training's l2: 0.0107316	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [4999]	training's rmse: 0.103296	training's l2: 0.01067	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# [5000]	training's rmse: 0.103078	training's l2: 0.010625	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# Did not meet early stopping. Best iteration is:
# [5000]	training's rmse: 0.103078	training's l2: 0.010625	valid_1's rmse: 5.48464e+09	valid_1's l2: 3.00813e+19
# LGBMRegressor(max_depth=15, min_child_samples=15, n_estimators=5000,
#               num_leaves=40, reg_alpha=0.01)

# %%
y_pred_train = model.predict(X_train_scaled)
y_pred_val = model.predict(X_val_scaled)
print('훈련 점수: ', rmse(y_train, y_pred_train))
print('검증 점수: ', rmse(y_val, y_pred_val))
# Out:
# 훈련 점수:  934712.591233063
# 검증 점수:  3.0081321895570096e+19

# %% [markdown]
# - cv 돌렸을 때 나온 best_prams 넣었을 때의 score가 가장 좋당
# - n_estimator가 너무 많은 것 같지만 n_estimator=5000, early_stopping_rounds=500 설정했을 때 점수가 가장 좋았다,,!

# %% [markdown]
# # 순열 중요도

# %%
# !pip install eli5

# %%
# 5cv 사용 모델 PI
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(clf.best_estimator_, random_state=42).fit(X_train, y_train)
eli5.show_weights(perm, feature_names = X_train.columns.tolist(), top=400)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0988
#
#                     &plusmn; 0.0151
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 선행종합지수_lag_6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.60%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0558
#
#                     &plusmn; 0.0082
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 국내총소득_lag
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0412
#
#                     &plusmn; 0.0079
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 KOSPI_lag6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0375
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 산업생산지수_lag_6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0172
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 P_금_lag6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0052
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국의대베트남수출_lag12m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0051
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 미국_산업생산지수_lag_6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0041
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국_수출금액_lag6m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0039
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국의대중국수출_lag6m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0039
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국의대홍콩수출_lag6m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0025
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국_수출금액_lag12m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0024
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 수출건수_lag12
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 중국_환율_lag6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국의대홍콩수출_lag12m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DowJones_lag6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0015
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 국내총생산_lag
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0015
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국의대베트남수출_lag6m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0015

# %%
# early stopping 사용 모델 PI
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(model, random_state=1).fit(X_train_scaled, y_train)
eli5.show_weights(perm, feature_names = X_train.columns.tolist(), top=400)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1032
#
#                     &plusmn; 0.0098
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 선행종합지수_lag_6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0582
#
#                     &plusmn; 0.0082
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 국내총소득_lag
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0446
#
#                     &plusmn; 0.0052
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 KOSPI_lag6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0364
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 산업생산지수_lag_6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0164
#
#                     &plusmn; 0.0028
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 P_금_lag6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0059
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 미국_산업생산지수_lag_6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0046
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국의대베트남수출_lag12m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0041
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국의대중국수출_lag6m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0040
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국_수출금액_lag6m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0036
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국의대홍콩수출_lag6m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0026
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국_수출금액_lag12m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0026
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 수출건수_lag12
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DowJones_lag6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 한국의대홍콩수출_lag12m
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 중국_환율_lag6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0016
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 수출물가_lag12
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0015
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 중국_실질실효환율_lag6
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0015

# %% [markdown]
# - early stopping 모델이랑 cv 돌린 모델 PI 같음!
# - 근데 당연함.. cv 돌려서 나온 파라미터를 early stopping 돌릴 때 넣었기 때문이지
#   - 바꿔서 해봐야 하나?
